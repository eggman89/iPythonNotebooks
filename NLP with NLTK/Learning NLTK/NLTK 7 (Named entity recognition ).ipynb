# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer
from nltk.tokenize import word_tokenize
import matplotlib
# %matplotlib inline

train_text = state_union.raw("2005-GWBush.txt")
sample_text = state_union.raw("2006-GWBush.txt")

cust_sent_token = PunktSentenceTokenizer(train_text)
tokenized = cust_sent_token.tokenize(sample_text)

def process_content():
    
    try:
        for i in tokenized:
            words = nltk.word_tokenize(i)
            tagged = nltk.pos_tag(words)
            
            namedEnt = nltk.ne_chunk(tagged)
            print (namedEnt)
        
            
    except Exception as e:
        print (str(e))
process_content()
# Out:
# (S
#   PRESIDENT/NNP
#   (PERSON GEORGE/NNP W./NNP BUSH/NNP)
#   'S/POS
#   (ORGANIZATION ADDRESS/NNP)
#   BEFORE/NNP
#   A/NNP
#   (ORGANIZATION JOINT/NNP)
#   SESSION/NNP
#   OF/NNP
#   THE/NNP
#   (ORGANIZATION CONGRESS/NNP)
#   ON/NNP
#   THE/NNP
#   (ORGANIZATION STATE/NNP)
#   OF/NNP
#   (ORGANIZATION THE/NNP)
#   (ORGANIZATION UNION/NNP)
#   January/NNP
#   31/CD
#   ,/,
#   2006/CD
#   THE/DT
#   PRESIDENT/NNP
#   :/:
#   Thank/NNP
#   you/PRP
#   all/DT
#   ./.)
# (S
#   (PERSON Mr./NNP Speaker/NNP)
#   ,/,
#   Vice/NNP
#   President/NNP
#   (PERSON Cheney/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   ,/,
#   members/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Supreme/NNP Court/NNP)
#   and/CC
#   diplomatic/JJ
#   corps/NNS
#   ,/,
#   distinguished/VBD
#   guests/NNS
#   ,/,
#   and/CC
#   fellow/JJ
#   citizens/NNS
#   :/:
#   Today/NN
#   our/PRP$
#   nation/NN
#   lost/VBD
#   a/DT
#   beloved/VBN
#   ,/,
#   graceful/JJ
#   ,/,
#   courageous/JJ
#   woman/NN
#   who/WP
#   called/VBN
#   (GPE America/NNP)
#   to/TO
#   its/PRP$
#   founding/NN
#   ideals/NNS
#   and/CC
#   carried/VBD
#   on/IN
#   a/DT
#   noble/JJ
#   dream/NN
#   ./.)
# (S
#   Tonight/NNP
#   we/PRP
#   are/VBP
#   comforted/VBN
#   by/IN
#   the/DT
#   hope/NN
#   of/IN
#   a/DT
#   glad/NN
#   reunion/NN
#   with/IN
#   the/DT
#   husband/NN
#   who/WP
#   was/VBD
#   taken/VBN
#   so/RB
#   long/RB
#   ago/RB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   grateful/JJ
#   for/IN
#   the/DT
#   good/NN
#   life/NN
#   of/IN
#   (ORGANIZATION Coretta/NNP Scott/NNP King/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   reacts/VBZ
#   to/TO
#   applause/VB
#   during/IN
#   his/PRP$
#   State/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (GPE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/IN
#   by/IN
#   (PERSON Eric/NNP)
#   DraperEvery/NNP
#   time/NN
#   I/PRP
#   'm/VBP
#   invited/VBN
#   to/TO
#   this/DT
#   rostrum/NN
#   ,/,
#   I/PRP
#   'm/VBP
#   humbled/VBN
#   by/IN
#   the/DT
#   privilege/NN
#   ,/,
#   and/CC
#   mindful/JJ
#   of/IN
#   the/DT
#   history/NN
#   we/PRP
#   've/VBP
#   seen/VBN
#   together/RP
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   gathered/VBN
#   under/IN
#   this/DT
#   Capitol/NNP
#   dome/NN
#   in/IN
#   moments/NNS
#   of/IN
#   national/JJ
#   mourning/NN
#   and/CC
#   national/JJ
#   achievement/NN
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   served/VBN
#   (GPE America/NNP)
#   through/IN
#   one/CD
#   of/IN
#   the/DT
#   most/RBS
#   consequential/JJ
#   periods/NNS
#   of/IN
#   our/PRP$
#   history/NN
#   --/:
#   and/CC
#   it/PRP
#   has/VBZ
#   been/VBN
#   my/PRP$
#   honor/NN
#   to/TO
#   serve/VB
#   with/IN
#   you/PRP
#   ./.)
# (S
#   In/IN
#   a/DT
#   system/NN
#   of/IN
#   two/CD
#   parties/NNS
#   ,/,
#   two/CD
#   chambers/NNS
#   ,/,
#   and/CC
#   two/CD
#   elected/VBN
#   branches/NNS
#   ,/,
#   there/EX
#   will/MD
#   always/RB
#   be/VB
#   differences/NNS
#   and/CC
#   debate/NN
#   ./.)
# (S
#   But/CC
#   even/RB
#   tough/JJ
#   debates/NNS
#   can/MD
#   be/VB
#   conducted/VBN
#   in/IN
#   a/DT
#   civil/JJ
#   tone/NN
#   ,/,
#   and/CC
#   our/PRP$
#   differences/NNS
#   can/MD
#   not/RB
#   be/VB
#   allowed/VBN
#   to/TO
#   harden/VB
#   into/IN
#   anger/NN
#   ./.)
# (S
#   To/TO
#   confront/VB
#   the/DT
#   great/JJ
#   issues/NNS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   must/MD
#   act/VB
#   in/IN
#   a/DT
#   spirit/NN
#   of/IN
#   goodwill/NN
#   and/CC
#   respect/NN
#   for/IN
#   one/CD
#   another/DT
#   --/:
#   and/CC
#   I/PRP
#   will/MD
#   do/VB
#   my/PRP$
#   part/NN
#   ./.)
# (S
#   Tonight/NNP
#   the/DT
#   state/NN
#   of/IN
#   our/PRP$
#   (ORGANIZATION Union/NNP)
#   is/VBZ
#   strong/JJ
#   --/:
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   make/VB
#   it/PRP
#   stronger/JJR
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   In/IN
#   this/DT
#   decisive/JJ
#   year/NN
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   will/MD
#   make/VB
#   choices/NNS
#   that/WDT
#   determine/NN
#   both/DT
#   the/DT
#   future/NN
#   and/CC
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   act/VB
#   confidently/RB
#   in/IN
#   pursuing/NN
#   the/DT
#   enemies/NNS
#   of/IN
#   freedom/NN
#   --/:
#   or/CC
#   retreat/VB
#   from/IN
#   our/PRP$
#   duties/NNS
#   in/IN
#   the/DT
#   hope/NN
#   of/IN
#   an/DT
#   easier/JJR
#   life/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   choose/VB
#   to/TO
#   build/VB
#   our/PRP$
#   prosperity/NN
#   by/IN
#   leading/VBG
#   the/DT
#   world/NN
#   economy/NN
#   --/:
#   or/CC
#   shut/VB
#   ourselves/NNS
#   off/IN
#   from/IN
#   trade/NN
#   and/CC
#   opportunity/NN
#   ./.)
# (S
#   In/IN
#   a/DT
#   complex/JJ
#   and/CC
#   challenging/VBG
#   time/NN
#   ,/,
#   the/DT
#   road/NN
#   of/IN
#   isolationism/NN
#   and/CC
#   protectionism/NN
#   may/MD
#   seem/VB
#   broad/JJ
#   and/CC
#   inviting/VBG
#   --/:
#   yet/RB
#   it/PRP
#   ends/VBZ
#   in/IN
#   danger/JJR
#   and/CC
#   decline/NN
#   ./.)
# (S
#   The/DT
#   only/JJ
#   way/NN
#   to/TO
#   protect/VB
#   our/PRP$
#   people/NNS
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   secure/VB
#   the/DT
#   peace/NN
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   control/NN
#   our/PRP$
#   destiny/NN
#   is/VBZ
#   by/IN
#   our/PRP$
#   leadership/NN
#   --/:
#   so/RB
#   the/DT
#   (GPE United/NNP States/NNPS)
#   of/IN
#   (GPE America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   lead/VB
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (GPE Abroad/NNP)
#   ,/,
#   our/PRP$
#   nation/NN
#   is/VBZ
#   committed/VBN
#   to/TO
#   an/DT
#   historic/JJ
#   ,/,
#   long-term/JJ
#   goal/NN
#   --/:
#   we/PRP
#   seek/VBP
#   the/DT
#   end/NN
#   of/IN
#   tyranny/NN
#   in/IN
#   our/PRP$
#   world/NN
#   ./.)
# (S
#   Some/DT
#   dismiss/NN
#   that/IN
#   goal/NN
#   as/IN
#   misguided/VBN
#   idealism/NN
#   ./.)
# (S
#   In/IN
#   reality/NN
#   ,/,
#   the/DT
#   future/NN
#   security/NN
#   of/IN
#   (GPE America/NNP)
#   depends/NNS
#   on/IN
#   it/PRP
#   ./.)
# (S
#   On/IN
#   September/NNP
#   the/DT
#   11th/JJ
#   ,/,
#   2001/CD
#   ,/,
#   we/PRP
#   found/VBD
#   that/IN
#   problems/NNS
#   originating/VBG
#   in/IN
#   a/DT
#   failed/VBN
#   and/CC
#   oppressive/JJ
#   state/NN
#   7,000/CD
#   miles/NNS
#   away/RB
#   could/MD
#   bring/VB
#   murder/NN
#   and/CC
#   destruction/NN
#   to/TO
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   Dictatorships/NNS
#   shelter/VBP
#   terrorists/NNS
#   ,/,
#   and/CC
#   feed/VBD
#   resentment/NN
#   and/CC
#   radicalism/NN
#   ,/,
#   and/CC
#   seek/VB
#   weapons/NNS
#   of/IN
#   mass/NN
#   destruction/NN
#   ./.)
# (S
#   Democracies/NNS
#   replace/VBP
#   resentment/NN
#   with/IN
#   hope/NN
#   ,/,
#   respect/NN
#   the/DT
#   rights/NNS
#   of/IN
#   their/PRP$
#   citizens/NNS
#   and/CC
#   their/PRP$
#   neighbors/NNS
#   ,/,
#   and/CC
#   join/VB
#   the/DT
#   fight/NN
#   against/IN
#   terror/NN
#   ./.)
# (S
#   Every/DT
#   step/NN
#   toward/IN
#   freedom/NN
#   in/IN
#   the/DT
#   world/NN
#   makes/VBZ
#   our/PRP$
#   country/NN
#   safer/NN
#   --/:
#   so/RB
#   we/PRP
#   will/MD
#   act/VB
#   boldly/RB
#   in/IN
#   freedom/NN
#   's/POS
#   cause/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Far/RB
#   from/IN
#   being/VBG
#   a/DT
#   hopeless/NN
#   dream/NN
#   ,/,
#   the/DT
#   advance/NN
#   of/IN
#   freedom/NN
#   is/VBZ
#   the/DT
#   great/JJ
#   story/NN
#   of/IN
#   our/PRP$
#   time/NN
#   ./.)
# (S
#   In/IN
#   1945/CD
#   ,/,
#   there/EX
#   were/VBD
#   about/IN
#   two/CD
#   dozen/NNS
#   lonely/RB
#   democracies/VBZ
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S Today/NN ,/, there/EX are/VBP 122/CD ./.)
# (S
#   And/CC
#   we/PRP
#   're/VBP
#   writing/VBG
#   a/DT
#   new/JJ
#   chapter/NN
#   in/IN
#   the/DT
#   story/NN
#   of/IN
#   self-government/JJ
#   --/:
#   with/IN
#   women/NNS
#   lining/VBG
#   up/RP
#   to/TO
#   vote/VB
#   in/IN
#   (GPE Afghanistan/NNP)
#   ,/,
#   and/CC
#   millions/NNS
#   of/IN
#   (GPE Iraqis/NNP)
#   marking/NN
#   their/PRP$
#   liberty/NN
#   with/IN
#   purple/NN
#   ink/NN
#   ,/,
#   and/CC
#   men/NNS
#   and/CC
#   women/NNS
#   from/IN
#   (GPE Lebanon/NNP)
#   to/TO
#   (GPE Egypt/NNP)
#   debating/NN
#   the/DT
#   rights/NNS
#   of/IN
#   individuals/NNS
#   and/CC
#   the/DT
#   necessity/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   At/IN
#   the/DT
#   start/NN
#   of/IN
#   2006/CD
#   ,/,
#   more/JJR
#   than/IN
#   half/PDT
#   the/DT
#   people/NNS
#   of/IN
#   our/PRP$
#   world/NN
#   live/NN
#   in/IN
#   democratic/JJ
#   nations/NNS
#   ./.)
# (S
#   And/CC
#   we/PRP
#   do/VBP
#   not/RB
#   forget/VB
#   the/DT
#   other/JJ
#   half/NN
#   --/:
#   in/IN
#   places/NNS
#   like/IN
#   (GSP Syria/NNP)
#   and/CC
#   (GPE Burma/NNP)
#   ,/,
#   (GPE Zimbabwe/NNP)
#   ,/,
#   (GPE North/NNP Korea/NNP)
#   ,/,
#   and/CC
#   (GPE Iran/NNP)
#   --/:
#   because/IN
#   the/DT
#   demands/NNS
#   of/IN
#   justice/NN
#   ,/,
#   and/CC
#   the/DT
#   peace/NN
#   of/IN
#   this/DT
#   world/NN
#   ,/,
#   require/VB
#   their/PRP$
#   freedom/NN
#   ,/,
#   as/IN
#   well/RB
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   delivers/NNS
#   his/PRP$
#   State/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (GPE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/IN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP No/NNP)
#   one/CD
#   can/MD
#   deny/VB
#   the/DT
#   success/NN
#   of/IN
#   freedom/NN
#   ,/,
#   but/CC
#   some/DT
#   men/NNS
#   rage/VBP
#   and/CC
#   fight/NN
#   against/IN
#   it/PRP
#   ./.)
# (S
#   And/CC
#   one/CD
#   of/IN
#   the/DT
#   main/JJ
#   sources/NNS
#   of/IN
#   reaction/NN
#   and/CC
#   opposition/NN
#   is/VBZ
#   radical/JJ
#   Islam/NNP
#   --/:
#   the/DT
#   perversion/NN
#   by/IN
#   a/DT
#   few/JJ
#   of/IN
#   a/DT
#   noble/JJ
#   faith/NN
#   into/IN
#   an/DT
#   ideology/NN
#   of/IN
#   terror/NN
#   and/CC
#   death/NN
#   ./.)
# (S
#   Terrorists/NNS
#   like/IN
#   bin/NN
#   Laden/NNP
#   are/VBP
#   serious/JJ
#   about/IN
#   mass/NN
#   murder/NN
#   --/:
#   and/CC
#   all/DT
#   of/IN
#   us/PRP
#   must/MD
#   take/VB
#   their/PRP$
#   declared/VBN
#   intentions/NNS
#   seriously/RB
#   ./.)
# (S
#   They/PRP
#   seek/VBP
#   to/TO
#   impose/VB
#   a/DT
#   heartless/NN
#   system/NN
#   of/IN
#   totalitarian/JJ
#   control/NN
#   throughout/IN
#   the/DT
#   (GPE Middle/NNP East/NNP)
#   ,/,
#   and/CC
#   arm/NN
#   themselves/NNS
#   with/IN
#   weapons/NNS
#   of/IN
#   mass/NN
#   murder/NN
#   ./.)
# (S
#   Their/PRP$
#   aim/NN
#   is/VBZ
#   to/TO
#   seize/VB
#   power/NN
#   in/IN
#   (GPE Iraq/NNP)
#   ,/,
#   and/CC
#   use/VB
#   it/PRP
#   as/IN
#   a/DT
#   safe/NN
#   haven/VBN
#   to/TO
#   launch/VB
#   attacks/NNS
#   against/IN
#   (GPE America/NNP)
#   and/CC
#   the/DT
#   world/NN
#   ./.)
# (S
#   Lacking/VBG
#   the/DT
#   military/JJ
#   strength/NN
#   to/TO
#   challenge/VB
#   us/PRP
#   directly/RB
#   ,/,
#   the/DT
#   terrorists/NNS
#   have/VBP
#   chosen/VBN
#   the/DT
#   weapon/NN
#   of/IN
#   fear/NN
#   ./.)
# (S
#   When/WRB
#   they/PRP
#   murder/VBP
#   children/NNS
#   at/IN
#   a/DT
#   school/NN
#   in/IN
#   (GPE Beslan/NNP)
#   ,/,
#   or/CC
#   blow/VB
#   up/RP
#   commuters/NNS
#   in/IN
#   (GPE London/NNP)
#   ,/,
#   or/CC
#   behead/VB
#   a/DT
#   bound/NN
#   captive/NN
#   ,/,
#   the/DT
#   terrorists/NNS
#   hope/VBP
#   these/DT
#   horrors/NNS
#   will/MD
#   break/VB
#   our/PRP$
#   will/MD
#   ,/,
#   allowing/VBG
#   the/DT
#   violent/NN
#   to/TO
#   inherit/VB
#   the/DT
#   (LOCATION Earth/NNP)
#   ./.)
# (S
#   But/CC
#   they/PRP
#   have/VBP
#   miscalculated/VBN
#   :/:
#   We/PRP
#   love/VBP
#   our/PRP$
#   freedom/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   fight/VB
#   to/TO
#   keep/VB
#   it/PRP
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   In/IN
#   a/DT
#   time/NN
#   of/IN
#   testing/NN
#   ,/,
#   we/PRP
#   can/MD
#   not/RB
#   find/VB
#   security/NN
#   by/IN
#   abandoning/NN
#   our/PRP$
#   commitments/NNS
#   and/CC
#   retreating/VBG
#   within/IN
#   our/PRP$
#   borders/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   were/VBD
#   to/TO
#   leave/VB
#   these/DT
#   vicious/JJ
#   attackers/NNS
#   alone/RB
#   ,/,
#   they/PRP
#   would/MD
#   not/RB
#   leave/VB
#   us/PRP
#   alone/RB
#   ./.)
# (S
#   They/PRP
#   would/MD
#   simply/RB
#   move/VB
#   the/DT
#   battlefield/NN
#   to/TO
#   our/PRP$
#   own/JJ
#   shores/NNS
#   ./.)
# (S There/EX is/VBZ no/DT peace/NN in/IN retreat/NN ./.)
# (S And/CC there/EX is/VBZ no/DT honor/NN in/IN retreat/NN ./.)
# (S
#   By/IN
#   allowing/NN
#   radical/JJ
#   Islam/NNP
#   to/TO
#   work/VB
#   its/PRP$
#   will/MD
#   --/:
#   by/IN
#   leaving/NN
#   an/DT
#   assaulted/JJ
#   world/NN
#   to/TO
#   fend/VB
#   for/IN
#   itself/PRP
#   --/:
#   we/PRP
#   would/MD
#   signal/VB
#   to/TO
#   all/DT
#   that/DT
#   we/PRP
#   no/DT
#   longer/NN
#   believe/VBP
#   in/IN
#   our/PRP$
#   own/JJ
#   ideals/NNS
#   ,/,
#   or/CC
#   even/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   courage/NN
#   ./.)
# (S
#   But/CC
#   our/PRP$
#   enemies/NNS
#   and/CC
#   our/PRP$
#   friends/NNS
#   can/MD
#   be/VB
#   certain/JJ
#   :/:
#   The/DT
#   (GPE United/NNP States/NNPS)
#   will/MD
#   not/RB
#   retreat/VB
#   from/IN
#   the/DT
#   world/NN
#   ,/,
#   and/CC
#   we/PRP
#   will/MD
#   never/RB
#   surrender/VB
#   to/TO
#   evil/VB
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (GPE America/NNP)
#   rejects/NNS
#   the/DT
#   false/NN
#   comfort/NN
#   of/IN
#   isolationism/NN
#   ./.)
# (S
#   We/PRP
#   are/VBP
#   the/DT
#   nation/NN
#   that/IN
#   saved/VBN
#   liberty/NN
#   in/IN
#   (GPE Europe/NNP)
#   ,/,
#   and/CC
#   liberated/VBD
#   death/NN
#   camps/NNS
#   ,/,
#   and/CC
#   helped/VBD
#   raise/VB
#   up/RP
#   democracies/NNS
#   ,/,
#   and/CC
#   faced/VBD
#   down/RP
#   an/DT
#   evil/JJ
#   empire/NN
#   ./.)
# (S
#   Once/RB
#   again/RB
#   ,/,
#   we/PRP
#   accept/VBP
#   the/DT
#   call/NN
#   of/IN
#   history/NN
#   to/TO
#   deliver/VB
#   the/DT
#   oppressed/VBN
#   and/CC
#   move/VB
#   this/DT
#   world/NN
#   toward/IN
#   peace/NN
#   ./.)
# (S
#   We/PRP
#   remain/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terror/NN
#   networks/NNS
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   killed/VBN
#   or/CC
#   captured/VBN
#   many/JJ
#   of/IN
#   their/PRP$
#   leaders/NNS
#   --/:
#   and/CC
#   for/IN
#   the/DT
#   others/NNS
#   ,/,
#   their/PRP$
#   day/NN
#   will/MD
#   come/VB
#   ./.)
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   greets/VBZ
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   after/IN
#   his/PRP$
#   State/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   the/DT
#   (GPE Capitol/NNP)
#   ,/,
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S 31/CD ,/, 2006/CD ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/IN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP We/NNP)
#   remain/NN
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (GPE Afghanistan/NNP)
#   ,/,
#   where/WRB
#   a/DT
#   fine/NN
#   President/NNP
#   and/CC
#   a/DT
#   (ORGANIZATION National/NNP Assembly/NNP)
#   are/VBP
#   fighting/VBG
#   terror/NN
#   while/IN
#   building/NN
#   the/DT
#   institutions/NNS
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   on/IN
#   the/DT
#   offensive/JJ
#   in/IN
#   (GPE Iraq/NNP)
#   ,/,
#   with/IN
#   a/DT
#   clear/JJ
#   plan/NN
#   for/IN
#   victory/NN
#   ./.)
# (S
#   (GPE First/NNP)
#   ,/,
#   we/PRP
#   're/VBP
#   helping/VBG
#   (GPE Iraqis/NNP)
#   build/NN
#   an/DT
#   inclusive/JJ
#   government/NN
#   ,/,
#   so/RB
#   that/IN
#   old/JJ
#   resentments/NNS
#   will/MD
#   be/VB
#   eased/VBN
#   and/CC
#   the/DT
#   insurgency/NN
#   will/MD
#   be/VB
#   marginalized/VBN
#   ./.)
# (S
#   (GPE Second/JJ)
#   ,/,
#   we/PRP
#   're/VBP
#   continuing/VBG
#   reconstruction/NN
#   efforts/NNS
#   ,/,
#   and/CC
#   helping/VBG
#   the/DT
#   (GPE Iraqi/NNP)
#   government/NN
#   to/TO
#   fight/NN
#   corruption/NN
#   and/CC
#   build/VB
#   a/DT
#   modern/JJ
#   economy/NN
#   ,/,
#   so/RB
#   all/DT
#   (GPE Iraqis/NNP)
#   can/MD
#   experience/VB
#   the/DT
#   benefits/NNS
#   of/IN
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   ,/,
#   third/JJ
#   ,/,
#   we/PRP
#   're/VBP
#   striking/VBG
#   terrorist/NN
#   targets/NNS
#   while/IN
#   we/PRP
#   train/VBP
#   (GPE Iraqi/NNP)
#   forces/NNS
#   that/WDT
#   are/VBP
#   increasingly/RB
#   capable/JJ
#   of/IN
#   defeating/NN
#   the/DT
#   enemy/NN
#   ./.)
# (S
#   (GPE Iraqis/NNP)
#   are/VBP
#   showing/VBG
#   their/PRP$
#   courage/NN
#   every/DT
#   day/NN
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   proud/VBN
#   to/TO
#   be/VB
#   their/PRP$
#   allies/NNS
#   in/IN
#   the/DT
#   cause/NN
#   of/IN
#   freedom/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Our/PRP$
#   work/NN
#   in/IN
#   (GPE Iraq/NNP)
#   is/VBZ
#   difficult/JJ
#   because/IN
#   our/PRP$
#   enemy/NN
#   is/VBZ
#   brutal/JJ
#   ./.)
# (S
#   But/CC
#   that/DT
#   brutality/NN
#   has/VBZ
#   not/RB
#   stopped/VBN
#   the/DT
#   dramatic/JJ
#   progress/NN
#   of/IN
#   a/DT
#   new/JJ
#   democracy/NN
#   ./.)
# (S
#   In/IN
#   less/JJR
#   than/IN
#   three/CD
#   years/NNS
#   ,/,
#   the/DT
#   nation/NN
#   has/VBZ
#   gone/VBN
#   from/IN
#   dictatorship/NN
#   to/TO
#   liberation/NN
#   ,/,
#   to/TO
#   sovereignty/NN
#   ,/,
#   to/TO
#   a/DT
#   constitution/NN
#   ,/,
#   to/TO
#   national/JJ
#   elections/NNS
#   ./.)
# (S
#   At/IN
#   the/DT
#   same/JJ
#   time/NN
#   ,/,
#   our/PRP$
#   coalition/NN
#   has/VBZ
#   been/VBN
#   relentless/JJ
#   in/IN
#   shutting/NN
#   off/IN
#   terrorist/NN
#   infiltration/NN
#   ,/,
#   clearing/VBG
#   out/RP
#   insurgent/NN
#   strongholds/NNS
#   ,/,
#   and/CC
#   turning/VBG
#   over/RP
#   territory/JJ
#   to/TO
#   (GPE Iraqi/NNP)
#   security/NN
#   forces/VBZ
#   ./.)
# (S
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   our/PRP$
#   plan/NN
#   for/IN
#   victory/NN
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   will/MD
#   of/IN
#   the/DT
#   (GPE Iraqi/NNP)
#   people/NNS
#   ;/:
#   I/PRP
#   am/VBP
#   confident/JJ
#   in/IN
#   the/DT
#   skill/NN
#   and/CC
#   spirit/NN
#   of/IN
#   our/PRP$
#   military/JJ
#   ./.)
# (S
#   (GPE Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   are/VBP
#   in/IN
#   this/DT
#   fight/NN
#   to/TO
#   win/VB
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   winning/VBG
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   The/DT
#   road/NN
#   of/IN
#   victory/NN
#   is/VBZ
#   the/DT
#   road/NN
#   that/IN
#   will/MD
#   take/VB
#   our/PRP$
#   troops/NNS
#   home/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   make/VBP
#   progress/NN
#   on/IN
#   the/DT
#   ground/NN
#   ,/,
#   and/CC
#   (GPE Iraqi/NNP)
#   forces/NNS
#   increasingly/RB
#   take/VB
#   the/DT
#   lead/NN
#   ,/,
#   we/PRP
#   should/MD
#   be/VB
#   able/JJ
#   to/TO
#   further/RBR
#   decrease/VB
#   our/PRP$
#   troop/NN
#   levels/NNS
#   --/:
#   but/CC
#   those/DT
#   decisions/NNS
#   will/MD
#   be/VB
#   made/VBN
#   by/IN
#   our/PRP$
#   military/JJ
#   commanders/NNS
#   ,/,
#   not/RB
#   by/IN
#   politicians/NNS
#   in/IN
#   (GPE Washington/NNP)
#   ,/,
#   D.C/NNP
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Our/PRP$
#   coalition/NN
#   has/VBZ
#   learned/VBN
#   from/IN
#   our/PRP$
#   experience/NN
#   in/IN
#   (GPE Iraq/NNP)
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   adjusted/VBN
#   our/PRP$
#   military/JJ
#   tactics/NNS
#   and/CC
#   changed/VBD
#   our/PRP$
#   approach/NN
#   to/TO
#   reconstruction/NN
#   ./.)
# (S
#   Along/IN
#   the/DT
#   way/NN
#   ,/,
#   we/PRP
#   have/VBP
#   benefitted/VBN
#   from/IN
#   responsible/JJ
#   criticism/NN
#   and/CC
#   counsel/NN
#   offered/VBD
#   by/IN
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   coming/VBG
#   year/NN
#   ,/,
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   reach/VB
#   out/RP
#   and/CC
#   seek/VB
#   your/PRP$
#   good/JJ
#   advice/NN
#   ./.)
# (S
#   Yet/CC
#   ,/,
#   there/EX
#   is/VBZ
#   a/DT
#   difference/NN
#   between/IN
#   responsible/JJ
#   criticism/NN
#   that/WDT
#   aims/VBZ
#   for/IN
#   success/NN
#   ,/,
#   and/CC
#   defeatism/NN
#   that/IN
#   refuses/NNS
#   to/TO
#   acknowledge/VB
#   anything/NN
#   but/CC
#   failure/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (PERSON Hindsight/NNP)
#   alone/RB
#   is/VBZ
#   not/RB
#   wisdom/NN
#   ,/,
#   and/CC
#   second-guessing/JJ
#   is/VBZ
#   not/RB
#   a/DT
#   strategy/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   With/IN
#   so/RB
#   much/RB
#   in/IN
#   the/DT
#   balance/NN
#   ,/,
#   those/DT
#   of/IN
#   us/PRP
#   in/IN
#   public/JJ
#   office/NN
#   have/VBP
#   a/DT
#   duty/NN
#   to/TO
#   speak/VB
#   with/IN
#   candor/NN
#   ./.)
# (S
#   A/DT
#   sudden/JJ
#   withdrawal/NN
#   of/IN
#   our/PRP$
#   forces/NNS
#   from/IN
#   (GPE Iraq/NNP)
#   would/MD
#   abandon/VB
#   our/PRP$
#   (GPE Iraqi/NNP)
#   allies/NNS
#   to/TO
#   death/NN
#   and/CC
#   prison/NN
#   ,/,
#   would/MD
#   put/VB
#   men/NNS
#   like/IN
#   bin/NN
#   (PERSON Laden/NNP)
#   and/CC
#   (GPE Zarqawi/NNP)
#   in/IN
#   charge/NN
#   of/IN
#   a/DT
#   strategic/JJ
#   country/NN
#   ,/,
#   and/CC
#   show/NN
#   that/IN
#   a/DT
#   pledge/NN
#   from/IN
#   (GPE America/NNP)
#   means/NNS
#   little/RB
#   ./.)
# (S
#   Members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   ,/,
#   however/RB
#   we/PRP
#   feel/VBP
#   about/IN
#   the/DT
#   decisions/NNS
#   and/CC
#   debates/NNS
#   of/IN
#   the/DT
#   past/JJ
#   ,/,
#   our/PRP$
#   nation/NN
#   has/VBZ
#   only/RB
#   one/CD
#   option/NN
#   :/:
#   We/PRP
#   must/MD
#   keep/VB
#   our/PRP$
#   word/NN
#   ,/,
#   defeat/NN
#   our/PRP$
#   enemies/NNS
#   ,/,
#   and/CC
#   stand/VBP
#   behind/IN
#   the/DT
#   (GPE American/NNP)
#   military/JJ
#   in/IN
#   this/DT
#   vital/JJ
#   mission/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (PERSON Laura/NNP)
#   (ORGANIZATION Bush/NNP)
#   is/VBZ
#   applauded/VBN
#   as/RB
#   she/PRP
#   is/VBZ
#   introduced/VBN
#   Tuesday/NNP
#   evening/NN
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   during/IN
#   the/DT
#   State/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP Address/NNP)
#   at/IN
#   (GPE United/NNP States/NNPS)
#   Capitol/NNP
#   in/IN
#   (GPE Washington/NNP)
#   ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/IN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP)
#   Our/NNP
#   men/NNS
#   and/CC
#   women/NNS
#   in/IN
#   uniform/NN
#   are/VBP
#   making/VBG
#   sacrifices/NNS
#   --/:
#   and/CC
#   showing/NN
#   a/DT
#   sense/NN
#   of/IN
#   duty/NN
#   stronger/JJR
#   than/IN
#   all/DT
#   fear/NN
#   ./.)
# (S
#   They/PRP
#   know/VBP
#   what/WP
#   it/PRP
#   's/VBZ
#   like/IN
#   to/TO
#   fight/NN
#   house/NN
#   to/TO
#   house/VB
#   in/IN
#   a/DT
#   maze/NN
#   of/IN
#   streets/NNS
#   ,/,
#   to/TO
#   wear/VB
#   heavy/JJ
#   gear/NN
#   in/IN
#   the/DT
#   desert/NN
#   heat/NN
#   ,/,
#   to/TO
#   see/VB
#   a/DT
#   comrade/NN
#   killed/VBD
#   by/IN
#   a/DT
#   roadside/JJ
#   bomb/NN
#   ./.)
# (S
#   And/CC
#   those/DT
#   who/WP
#   know/RB
#   the/DT
#   costs/NNS
#   also/RB
#   know/VBP
#   the/DT
#   stakes/NNS
#   ./.)
# (S
#   (PERSON Marine/NNP)
#   Staff/NNP
#   Sergeant/NNP
#   (PERSON Dan/NNP Clay/NNP)
#   was/VBD
#   killed/VBN
#   last/JJ
#   month/NN
#   fighting/VBG
#   in/IN
#   (GPE Fallujah/NNP)
#   ./.)
# (S
#   He/PRP
#   left/VBD
#   behind/IN
#   a/DT
#   letter/NN
#   to/TO
#   his/PRP$
#   family/NN
#   ,/,
#   but/CC
#   his/PRP$
#   words/NNS
#   could/MD
#   just/RB
#   as/IN
#   well/RB
#   be/VB
#   addressed/VBN
#   to/TO
#   every/DT
#   (GPE American/NNP)
#   ./.)
# (S
#   Here/RB
#   is/VBZ
#   what/WP
#   (PERSON Dan/NNP)
#   wrote/VBD
#   :/:
#   ``/``
#   I/PRP
#   know/VBP
#   what/WP
#   honor/NN
#   is/VBZ
#   ./.)
# (S
#   .../:
#   It/PRP
#   has/VBZ
#   been/VBN
#   an/DT
#   honor/NN
#   to/TO
#   protect/VB
#   and/CC
#   serve/VB
#   all/DT
#   of/IN
#   you/PRP
#   ./.)
# (S
#   I/PRP
#   faced/VBD
#   death/NN
#   with/IN
#   the/DT
#   secure/NN
#   knowledge/NN
#   that/WDT
#   you/PRP
#   would/MD
#   not/RB
#   have/VB
#   to/TO
#   .../:
#   ./.)
# (S Never/RB falter/JJR !/.)
# (S
#   Do/NNP
#   n't/RB
#   hesitate/VB
#   to/TO
#   honor/VB
#   and/CC
#   support/NN
#   those/DT
#   of/IN
#   us/PRP
#   who/WP
#   have/VBP
#   the/DT
#   honor/NN
#   of/IN
#   protecting/VBG
#   that/IN
#   which/WDT
#   is/VBZ
#   worth/JJ
#   protecting/NN
#   ./.
#   ''/'')
# (S
#   Staff/NN
#   (PERSON Sergeant/NNP Dan/NNP Clay/NNP)
#   's/POS
#   wife/NN
#   ,/,
#   (PERSON Lisa/NNP)
#   ,/,
#   and/CC
#   his/PRP$
#   mom/NN
#   and/CC
#   dad/VBD
#   ,/,
#   (PERSON Sara/NNP Jo/NNP)
#   and/CC
#   (PERSON Bud/NNP)
#   ,/,
#   are/VBP
#   with/IN
#   us/PRP
#   this/DT
#   evening/NN
#   ./.)
# (S (GPE Welcome/NNP) ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Our/PRP$
#   nation/NN
#   is/VBZ
#   grateful/JJ
#   to/TO
#   the/DT
#   fallen/NN
#   ,/,
#   who/WP
#   live/JJ
#   in/IN
#   the/DT
#   memory/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   grateful/JJ
#   to/TO
#   all/DT
#   who/WP
#   volunteer/NN
#   to/TO
#   wear/VB
#   our/PRP$
#   nation/NN
#   's/POS
#   uniform/NN
#   --/:
#   and/CC
#   as/IN
#   we/PRP
#   honor/CC
#   our/PRP$
#   brave/NN
#   troops/NNS
#   ,/,
#   let/VB
#   us/PRP
#   never/RB
#   forget/VB
#   the/DT
#   sacrifices/NNS
#   of/IN
#   (GPE America/NNP)
#   's/POS
#   military/JJ
#   families/NNS
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Our/PRP$
#   offensive/JJ
#   against/IN
#   terror/NN
#   involves/NNS
#   more/RBR
#   than/IN
#   military/JJ
#   action/NN
#   ./.)
# (S
#   Ultimately/RB
#   ,/,
#   the/DT
#   only/JJ
#   way/NN
#   to/TO
#   defeat/VB
#   the/DT
#   terrorists/NNS
#   is/VBZ
#   to/TO
#   defeat/VB
#   their/PRP$
#   dark/NN
#   vision/NN
#   of/IN
#   hatred/VBN
#   and/CC
#   fear/NN
#   by/IN
#   offering/NN
#   the/DT
#   hopeful/JJ
#   alternative/NN
#   of/IN
#   political/JJ
#   freedom/NN
#   and/CC
#   peaceful/JJ
#   change/NN
#   ./.)
# (S
#   So/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   of/IN
#   (GPE America/NNP)
#   supports/NNS
#   democratic/JJ
#   reform/NN
#   across/IN
#   the/DT
#   broader/JJR
#   (GPE Middle/NNP East/NNP)
#   ./.)
# (S
#   Elections/NNS
#   are/VBP
#   vital/JJ
#   ,/,
#   but/CC
#   they/PRP
#   are/VBP
#   only/RB
#   the/DT
#   beginning/NN
#   ./.)
# (S
#   Raising/VBG
#   up/IN
#   a/DT
#   democracy/NN
#   requires/VBZ
#   the/DT
#   rule/NN
#   of/IN
#   law/NN
#   ,/,
#   and/CC
#   protection/NN
#   of/IN
#   minorities/NNS
#   ,/,
#   and/CC
#   strong/JJ
#   ,/,
#   accountable/JJ
#   institutions/NNS
#   that/WDT
#   last/JJ
#   longer/NN
#   than/IN
#   a/DT
#   single/JJ
#   vote/NN
#   ./.)
# (S
#   The/DT
#   great/JJ
#   people/NNS
#   of/IN
#   (GPE Egypt/NNP)
#   have/VBP
#   voted/VBN
#   in/IN
#   a/DT
#   multi-party/JJ
#   presidential/JJ
#   election/NN
#   --/:
#   and/CC
#   now/RB
#   their/PRP$
#   government/NN
#   should/MD
#   open/VB
#   paths/NNS
#   of/IN
#   peaceful/JJ
#   opposition/NN
#   that/WDT
#   will/MD
#   reduce/VB
#   the/DT
#   appeal/NN
#   of/IN
#   radicalism/NN
#   ./.)
# (S
#   The/DT
#   (GPE Palestinian/NNP)
#   people/NNS
#   have/VBP
#   voted/VBN
#   in/IN
#   elections/NNS
#   ./.)
# (S
#   And/CC
#   now/RB
#   the/DT
#   leaders/NNS
#   of/IN
#   (GPE Hamas/NNP)
#   must/MD
#   recognize/VB
#   (GPE Israel/NNP)
#   ,/,
#   disarm/NN
#   ,/,
#   reject/NN
#   terrorism/NN
#   ,/,
#   and/CC
#   work/NN
#   for/IN
#   lasting/NN
#   peace/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (GPE Saudi/NNP)
#   (PERSON Arabia/NNP)
#   has/VBZ
#   taken/VBN
#   the/DT
#   first/JJ
#   steps/NNS
#   of/IN
#   reform/NN
#   --/:
#   now/RB
#   it/PRP
#   can/MD
#   offer/VB
#   its/PRP$
#   people/NNS
#   a/DT
#   better/JJR
#   future/JJ
#   by/IN
#   pressing/NN
#   forward/RB
#   with/IN
#   those/DT
#   efforts/NNS
#   ./.)
# (S
#   Democracies/NNS
#   in/IN
#   the/DT
#   (GPE Middle/NNP East/NNP)
#   will/MD
#   not/RB
#   look/VB
#   like/IN
#   our/PRP$
#   own/JJ
#   ,/,
#   because/IN
#   they/PRP
#   will/MD
#   reflect/VB
#   the/DT
#   traditions/NNS
#   of/IN
#   their/PRP$
#   own/JJ
#   citizens/NNS
#   ./.)
# (S
#   Yet/CC
#   liberty/NN
#   is/VBZ
#   the/DT
#   future/NN
#   of/IN
#   every/DT
#   nation/NN
#   in/IN
#   the/DT
#   (GPE Middle/NNP East/NNP)
#   ,/,
#   because/IN
#   liberty/NN
#   is/VBZ
#   the/DT
#   right/NN
#   and/CC
#   hope/NN
#   of/IN
#   all/DT
#   humanity/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   President/NNP
#   (PERSON George/NNP W./NNP Bush/NNP)
#   waves/VBZ
#   toward/IN
#   the/DT
#   upper/JJ
#   visitors/NNS
#   gallery/VBP
#   of/IN
#   the/DT
#   (ORGANIZATION House/NNP)
#   Chamber/NNP
#   following/VBG
#   his/PRP$
#   State/NNP
#   of/IN
#   the/DT
#   (ORGANIZATION Union/NNP)
#   remarks/VBZ
#   Tuesday/NNP
#   ,/,
#   (PERSON Jan/NNP)
#   ./.)
# (S
#   31/CD
#   ,/,
#   2006/CD
#   at/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   Capitol/NNP
#   ./.)
# (S
#   (FACILITY White/NNP)
#   (ORGANIZATION House/NNP)
#   photo/IN
#   by/IN
#   (PERSON Eric/NNP Draper/NNP)
#   The/NNP
#   same/JJ
#   is/VBZ
#   true/JJ
#   of/IN
#   (GPE Iran/NNP)
#   ,/,
#   a/DT
#   nation/NN
#   now/RB
#   held/VBN
#   hostage/NN
#   by/IN
#   a/DT
#   small/JJ
#   clerical/JJ
#   elite/NN
#   that/WDT
#   is/VBZ
#   isolating/VBG
#   and/CC
#   repressing/VBG
#   its/PRP$
#   people/NNS
#   ./.)
# (S
#   The/DT
#   regime/NN
#   in/IN
#   that/DT
#   country/NN
#   sponsors/NNS
#   terrorists/VBZ
#   in/IN
#   the/DT
#   (GPE Palestinian/NNP)
#   territories/VBZ
#   and/CC
#   in/IN
#   (GPE Lebanon/NNP)
#   --/:
#   and/CC
#   that/IN
#   must/MD
#   come/VB
#   to/TO
#   an/DT
#   end/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   The/DT
#   (GPE Iranian/NNP)
#   government/NN
#   is/VBZ
#   defying/VBG
#   the/DT
#   world/NN
#   with/IN
#   its/PRP$
#   nuclear/JJ
#   ambitions/NNS
#   ,/,
#   and/CC
#   the/DT
#   nations/NNS
#   of/IN
#   the/DT
#   world/NN
#   must/MD
#   not/RB
#   permit/VB
#   the/DT
#   (GPE Iranian/NNP)
#   regime/NN
#   to/TO
#   gain/VB
#   nuclear/JJ
#   weapons/NNS
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (GPE America/NNP)
#   will/MD
#   continue/VB
#   to/TO
#   rally/RB
#   the/DT
#   world/NN
#   to/TO
#   confront/VB
#   these/DT
#   threats/NNS
#   ./.)
# (S
#   (GPE Tonight/NNP)
#   ,/,
#   let/VB
#   me/PRP
#   speak/VB
#   directly/RB
#   to/TO
#   the/DT
#   citizens/NNS
#   of/IN
#   (GPE Iran/NNP)
#   :/:
#   (GPE America/NNP)
#   respects/NNS
#   you/PRP
#   ,/,
#   and/CC
#   we/PRP
#   respect/VBP
#   your/PRP$
#   country/NN
#   ./.)
# (S
#   We/PRP
#   respect/VBP
#   your/PRP$
#   right/NN
#   to/TO
#   choose/VB
#   your/PRP$
#   own/JJ
#   future/JJ
#   and/CC
#   win/NN
#   your/PRP$
#   own/JJ
#   freedom/NN
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   nation/NN
#   hopes/NNS
#   one/CD
#   day/NN
#   to/TO
#   be/VB
#   the/DT
#   closest/JJS
#   of/IN
#   friends/NNS
#   with/IN
#   a/DT
#   free/JJ
#   and/CC
#   democratic/JJ
#   (GPE Iran/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   To/TO
#   overcome/VB
#   dangers/NNS
#   in/IN
#   our/PRP$
#   world/NN
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   take/VB
#   the/DT
#   offensive/JJ
#   by/IN
#   encouraging/NN
#   economic/JJ
#   progress/NN
#   ,/,
#   and/CC
#   fighting/VBG
#   disease/NN
#   ,/,
#   and/CC
#   spreading/VBG
#   hope/NN
#   in/IN
#   hopeless/NN
#   lands/NNS
#   ./.)
# (S
#   (GPE Isolationism/NNP)
#   would/MD
#   not/RB
#   only/RB
#   tie/VB
#   our/PRP$
#   hands/NNS
#   in/IN
#   fighting/VBG
#   enemies/NNS
#   ,/,
#   it/PRP
#   would/MD
#   keep/VB
#   us/PRP
#   from/IN
#   helping/VBG
#   our/PRP$
#   friends/NNS
#   in/IN
#   desperate/NN
#   need/NN
#   ./.)
# (S
#   We/PRP
#   show/VBP
#   compassion/NN
#   abroad/RB
#   because/IN
#   (GSP Americans/NNPS)
#   believe/VBP
#   in/IN
#   the/DT
#   God-given/JJ
#   dignity/NN
#   and/CC
#   worth/NN
#   of/IN
#   a/DT
#   villager/NN
#   with/IN
#   HIV/AIDS/NNS
#   ,/,
#   or/CC
#   an/DT
#   infant/JJ
#   with/IN
#   malaria/NN
#   ,/,
#   or/CC
#   a/DT
#   refugee/NN
#   fleeing/VBG
#   genocide/NN
#   ,/,
#   or/CC
#   a/DT
#   young/JJ
#   girl/NN
#   sold/VBD
#   into/IN
#   slavery/NN
#   ./.)
# (S
#   We/PRP
#   also/RB
#   show/VBP
#   compassion/NN
#   abroad/RB
#   because/IN
#   regions/NNS
#   overwhelmed/VBN
#   by/IN
#   poverty/NN
#   ,/,
#   corruption/NN
#   ,/,
#   and/CC
#   despair/JJ
#   are/VBP
#   sources/NNS
#   of/IN
#   terrorism/NN
#   ,/,
#   and/CC
#   organized/VBD
#   crime/NN
#   ,/,
#   and/CC
#   human/JJ
#   trafficking/NN
#   ,/,
#   and/CC
#   the/DT
#   drug/NN
#   trade/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   you/PRP
#   and/CC
#   I/PRP
#   have/VBP
#   taken/VBN
#   unprecedented/VBN
#   action/NN
#   to/TO
#   fight/NN
#   (ORGANIZATION AIDS/NNP)
#   and/CC
#   malaria/VB
#   ,/,
#   expand/CC
#   the/DT
#   education/NN
#   of/IN
#   girls/NNS
#   ,/,
#   and/CC
#   reward/NN
#   developing/VBG
#   nations/NNS
#   that/WDT
#   are/VBP
#   moving/VBG
#   forward/RB
#   with/IN
#   economic/JJ
#   and/CC
#   political/JJ
#   reform/NN
#   ./.)
# (S
#   For/IN
#   people/NNS
#   everywhere/RB
#   ,/,
#   the/DT
#   (GPE United/NNP States/NNPS)
#   is/VBZ
#   a/DT
#   partner/NN
#   for/IN
#   a/DT
#   better/JJR
#   life/NN
#   ./.)
# (S
#   Short-changing/JJ
#   these/DT
#   efforts/NNS
#   would/MD
#   increase/VB
#   the/DT
#   suffering/NN
#   and/CC
#   chaos/NNS
#   of/IN
#   our/PRP$
#   world/NN
#   ,/,
#   undercut/NN
#   our/PRP$
#   long-term/JJ
#   security/NN
#   ,/,
#   and/CC
#   dull/JJ
#   the/DT
#   conscience/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   to/TO
#   serve/VB
#   the/DT
#   interests/NNS
#   of/IN
#   (GPE America/NNP)
#   by/IN
#   showing/NN
#   the/DT
#   compassion/NN
#   of/IN
#   (GPE America/NNP)
#   ./.)
# (S
#   Our/PRP$
#   country/NN
#   must/MD
#   also/RB
#   remain/VB
#   on/IN
#   the/DT
#   offensive/JJ
#   against/IN
#   terrorism/NN
#   here/RB
#   at/IN
#   home/NN
#   ./.)
# (S
#   The/DT
#   enemy/NN
#   has/VBZ
#   not/RB
#   lost/VBN
#   the/DT
#   desire/NN
#   or/CC
#   capability/NN
#   to/TO
#   attack/VB
#   us/PRP
#   ./.)
# (S
#   Fortunately/RB
#   ,/,
#   this/DT
#   nation/NN
#   has/VBZ
#   superb/NN
#   professionals/NNS
#   in/IN
#   law/NN
#   enforcement/NN
#   ,/,
#   intelligence/NN
#   ,/,
#   the/DT
#   military/JJ
#   ,/,
#   and/CC
#   homeland/NN
#   security/NN
#   ./.)
# (S
#   These/DT
#   men/NNS
#   and/CC
#   women/NNS
#   are/VBP
#   dedicating/VBG
#   their/PRP$
#   lives/NNS
#   ,/,
#   protecting/VBG
#   us/PRP
#   all/DT
#   ,/,
#   and/CC
#   they/PRP
#   deserve/VBP
#   our/PRP$
#   support/NN
#   and/CC
#   our/PRP$
#   thanks/NNS
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   They/PRP
#   also/RB
#   deserve/VBP
#   the/DT
#   same/JJ
#   tools/NNS
#   they/PRP
#   already/RB
#   use/VBP
#   to/TO
#   fight/NN
#   drug/NN
#   trafficking/NN
#   and/CC
#   organized/VBD
#   crime/NN
#   --/:
#   so/RB
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   reauthorize/VB
#   the/DT
#   (ORGANIZATION Patriot/NNP Act/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   It/PRP
#   is/VBZ
#   said/VBN
#   that/IN
#   prior/RB
#   to/TO
#   the/DT
#   attacks/NNS
#   of/IN
#   September/NNP
#   the/DT
#   11th/JJ
#   ,/,
#   our/PRP$
#   government/NN
#   failed/VBD
#   to/TO
#   connect/VB
#   the/DT
#   dots/NNS
#   of/IN
#   the/DT
#   conspiracy/NN
#   ./.)
# (S
#   We/PRP
#   now/RB
#   know/VBP
#   that/IN
#   two/CD
#   of/IN
#   the/DT
#   hijackers/NNS
#   in/IN
#   the/DT
#   (GPE United/NNP States/NNPS)
#   placed/VBD
#   telephone/NN
#   calls/NNS
#   to/TO
#   al/JJ
#   Qaeda/NNP
#   operatives/NNS
#   overseas/RB
#   ./.)
# (S
#   But/CC
#   we/PRP
#   did/VBD
#   not/RB
#   know/VB
#   about/IN
#   their/PRP$
#   plans/NNS
#   until/IN
#   it/PRP
#   was/VBD
#   too/RB
#   late/JJ
#   ./.)
# (S
#   So/IN
#   to/TO
#   prevent/VB
#   another/DT
#   attack/NN
#   --/:
#   based/VBN
#   on/IN
#   authority/NN
#   given/VBN
#   to/TO
#   me/PRP
#   by/IN
#   the/DT
#   (ORGANIZATION Constitution/NNP)
#   and/CC
#   by/IN
#   statute/NN
#   --/:
#   I/PRP
#   have/VBP
#   authorized/VBN
#   a/DT
#   terrorist/NN
#   surveillance/NN
#   program/NN
#   to/TO
#   aggressively/RB
#   pursue/VB
#   the/DT
#   international/JJ
#   communications/NNS
#   of/IN
#   suspected/VBN
#   al/JJ
#   Qaeda/NNP
#   operatives/NNS
#   and/CC
#   affiliates/NNS
#   to/TO
#   and/CC
#   from/IN
#   (GPE America/NNP)
#   ./.)
# (S
#   Previous/JJ
#   Presidents/NNS
#   have/VBP
#   used/VBN
#   the/DT
#   same/JJ
#   constitutional/JJ
#   authority/NN
#   I/PRP
#   have/VBP
#   ,/,
#   and/CC
#   federal/JJ
#   courts/NNS
#   have/VBP
#   approved/VBN
#   the/DT
#   use/NN
#   of/IN
#   that/DT
#   authority/NN
#   ./.)
# (S
#   (GPE Appropriate/NNP)
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   have/VBP
#   been/VBN
#   kept/VBN
#   informed/VBN
#   ./.)
# (S
#   The/DT
#   terrorist/NN
#   surveillance/NN
#   program/NN
#   has/VBZ
#   helped/VBN
#   prevent/NN
#   terrorist/NN
#   attacks/NNS
#   ./.)
# (S
#   It/PRP
#   remains/VBZ
#   essential/JJ
#   to/TO
#   the/DT
#   security/NN
#   of/IN
#   (GPE America/NNP)
#   ./.)
# (S
#   If/IN
#   there/EX
#   are/VBP
#   people/NNS
#   inside/IN
#   our/PRP$
#   country/NN
#   who/WP
#   are/VBP
#   talking/VBG
#   with/IN
#   al/JJ
#   Qaeda/NNP
#   ,/,
#   we/PRP
#   want/VBP
#   to/TO
#   know/VB
#   about/IN
#   it/PRP
#   ,/,
#   because/IN
#   we/PRP
#   will/MD
#   not/RB
#   sit/VB
#   back/RB
#   and/CC
#   wait/VB
#   to/TO
#   be/VB
#   hit/VBN
#   again/RB
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   In/IN
#   all/DT
#   these/DT
#   areas/NNS
#   --/:
#   from/IN
#   the/DT
#   disruption/NN
#   of/IN
#   terror/NN
#   networks/NNS
#   ,/,
#   to/TO
#   victory/NN
#   in/IN
#   (GPE Iraq/NNP)
#   ,/,
#   to/TO
#   the/DT
#   spread/NN
#   of/IN
#   freedom/NN
#   and/CC
#   hope/NN
#   in/IN
#   troubled/JJ
#   regions/NNS
#   --/:
#   we/PRP
#   need/VBP
#   the/DT
#   support/NN
#   of/IN
#   our/PRP$
#   friends/NNS
#   and/CC
#   allies/NNS
#   ./.)
# (S
#   To/TO
#   draw/VB
#   that/IN
#   support/NN
#   ,/,
#   we/PRP
#   must/MD
#   always/RB
#   be/VB
#   clear/JJ
#   in/IN
#   our/PRP$
#   principles/NNS
#   and/CC
#   willing/JJ
#   to/TO
#   act/VB
#   ./.)
# (S
#   The/DT
#   only/JJ
#   alternative/NN
#   to/TO
#   (GPE American/JJ)
#   leadership/NN
#   is/VBZ
#   a/DT
#   dramatically/RB
#   more/RBR
#   dangerous/JJ
#   and/CC
#   anxious/JJ
#   world/NN
#   ./.)
# (S
#   Yet/CC
#   we/PRP
#   also/RB
#   choose/VBP
#   to/TO
#   lead/VB
#   because/IN
#   it/PRP
#   is/VBZ
#   a/DT
#   privilege/NN
#   to/TO
#   serve/VB
#   the/DT
#   values/NNS
#   that/WDT
#   gave/VBD
#   us/PRP
#   birth/JJ
#   ./.)
# (S
#   (GPE American/NNP)
#   leaders/NNS
#   --/:
#   from/IN
#   (GPE Roosevelt/NNP)
#   to/TO
#   (PERSON Truman/NNP)
#   to/TO
#   (PERSON Kennedy/NNP)
#   to/TO
#   (GPE Reagan/NNP)
#   --/:
#   rejected/VBD
#   isolation/NN
#   and/CC
#   retreat/NN
#   ,/,
#   because/IN
#   they/PRP
#   knew/VBD
#   that/IN
#   (GPE America/NNP)
#   is/VBZ
#   always/RB
#   more/RBR
#   secure/JJ
#   when/WRB
#   freedom/NN
#   is/VBZ
#   on/IN
#   the/DT
#   march/NN
#   ./.)
# (S
#   Our/PRP$
#   own/JJ
#   generation/NN
#   is/VBZ
#   in/IN
#   a/DT
#   long/JJ
#   war/NN
#   against/IN
#   a/DT
#   determined/VBN
#   enemy/NN
#   --/:
#   a/DT
#   war/NN
#   that/WDT
#   will/MD
#   be/VB
#   fought/VBN
#   by/IN
#   Presidents/NNP
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   who/WP
#   will/MD
#   need/VB
#   steady/JJ
#   bipartisan/NN
#   support/NN
#   from/IN
#   the/DT
#   (ORGANIZATION Congress/NNP)
#   ./.)
# (S And/CC tonight/VBD I/PRP ask/VBP for/IN yours/NNS ./.)
# (S
#   Together/RB
#   ,/,
#   let/VB
#   us/PRP
#   protect/VB
#   our/PRP$
#   country/NN
#   ,/,
#   support/NN
#   the/DT
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   defend/NN
#   us/PRP
#   ,/,
#   and/CC
#   lead/VB
#   this/DT
#   world/NN
#   toward/IN
#   freedom/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Here/RB
#   at/IN
#   home/NN
#   ,/,
#   (GPE America/NNP)
#   also/RB
#   has/VBZ
#   a/DT
#   great/JJ
#   opportunity/NN
#   :/:
#   We/PRP
#   will/MD
#   build/VB
#   the/DT
#   prosperity/NN
#   of/IN
#   our/PRP$
#   country/NN
#   by/IN
#   strengthening/NN
#   our/PRP$
#   economic/JJ
#   leadership/NN
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   Our/PRP$
#   economy/NN
#   is/VBZ
#   healthy/JJ
#   and/CC
#   vigorous/JJ
#   ,/,
#   and/CC
#   growing/VBG
#   faster/NN
#   than/IN
#   other/JJ
#   major/JJ
#   industrialized/JJ
#   nations/NNS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   two-and-a-half/NN
#   years/NNS
#   ,/,
#   (GPE America/NNP)
#   has/VBZ
#   created/VBN
#   4.6/CD
#   million/CD
#   new/JJ
#   jobs/NNS
#   --/:
#   more/RBR
#   than/IN
#   (GPE Japan/NNP)
#   and/CC
#   the/DT
#   (ORGANIZATION European/NNP Union/NNP)
#   combined/VBD
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Even/RB
#   in/IN
#   the/DT
#   face/NN
#   of/IN
#   higher/JJR
#   energy/NN
#   prices/NNS
#   and/CC
#   natural/JJ
#   disasters/NNS
#   ,/,
#   the/DT
#   (GPE American/NNP)
#   people/NNS
#   have/VBP
#   turned/VBN
#   in/IN
#   an/DT
#   economic/JJ
#   performance/NN
#   that/WDT
#   is/VBZ
#   the/DT
#   envy/NN
#   of/IN
#   the/DT
#   world/NN
#   ./.)
# (S
#   The/DT
#   (GPE American/NNP)
#   economy/NN
#   is/VBZ
#   preeminent/NN
#   ,/,
#   but/CC
#   we/PRP
#   can/MD
#   not/RB
#   afford/VB
#   to/TO
#   be/VB
#   complacent/JJ
#   ./.)
# (S
#   In/IN
#   a/DT
#   dynamic/JJ
#   world/NN
#   economy/NN
#   ,/,
#   we/PRP
#   are/VBP
#   seeing/VBG
#   new/JJ
#   competitors/NNS
#   ,/,
#   like/IN
#   (GPE China/NNP)
#   and/CC
#   (GPE India/NNP)
#   ,/,
#   and/CC
#   this/DT
#   creates/NNS
#   uncertainty/NN
#   ,/,
#   which/WDT
#   makes/VBZ
#   it/PRP
#   easier/JJR
#   to/TO
#   feed/VB
#   people/NNS
#   's/POS
#   fears/NNS
#   ./.)
# (S
#   So/IN
#   we/PRP
#   're/VBP
#   seeing/VBG
#   some/DT
#   old/JJ
#   temptations/NNS
#   return/VBP
#   ./.)
# (S
#   Protectionists/NNS
#   want/VBP
#   to/TO
#   escape/NN
#   competition/NN
#   ,/,
#   pretending/VBG
#   that/IN
#   we/PRP
#   can/MD
#   keep/VB
#   our/PRP$
#   high/JJ
#   standard/JJ
#   of/IN
#   living/NN
#   while/IN
#   walling/VBG
#   off/IN
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Others/NNS
#   say/VBP
#   that/IN
#   the/DT
#   government/NN
#   needs/VBZ
#   to/TO
#   take/VB
#   a/DT
#   larger/JJR
#   role/NN
#   in/IN
#   directing/NN
#   the/DT
#   economy/NN
#   ,/,
#   centralizing/VBG
#   more/JJR
#   power/NN
#   in/IN
#   (GPE Washington/NNP)
#   and/CC
#   increasing/VBG
#   taxes/NNS
#   ./.)
# (S
#   We/PRP
#   hear/VBP
#   claims/NNS
#   that/IN
#   immigrants/NNS
#   are/VBP
#   somehow/RB
#   bad/JJ
#   for/IN
#   the/DT
#   economy/NN
#   --/:
#   even/JJ
#   though/IN
#   this/DT
#   economy/NN
#   could/MD
#   not/RB
#   function/VB
#   without/IN
#   them/PRP
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   All/DT
#   these/DT
#   are/VBP
#   forms/NNS
#   of/IN
#   economic/JJ
#   retreat/NN
#   ,/,
#   and/CC
#   they/PRP
#   lead/VBP
#   in/IN
#   the/DT
#   same/JJ
#   direction/NN
#   --/:
#   toward/IN
#   a/DT
#   stagnant/JJ
#   and/CC
#   second-rate/JJ
#   economy/NN
#   ./.)
# (S
#   Tonight/NNP
#   I/PRP
#   will/MD
#   set/VB
#   out/RP
#   a/DT
#   better/JJR
#   path/NN
#   :/:
#   an/DT
#   agenda/NN
#   for/IN
#   a/DT
#   nation/NN
#   that/WDT
#   competes/VBZ
#   with/IN
#   confidence/NN
#   ;/:
#   an/DT
#   agenda/NN
#   that/IN
#   will/MD
#   raise/VB
#   standards/NNS
#   of/IN
#   living/VBG
#   and/CC
#   generate/JJ
#   new/JJ
#   jobs/NNS
#   ./.)
# (S
#   (GPE Americans/NNPS)
#   should/MD
#   not/RB
#   fear/VB
#   our/PRP$
#   economic/JJ
#   future/JJ
#   ,/,
#   because/IN
#   we/PRP
#   intend/VBP
#   to/TO
#   shape/NN
#   it/PRP
#   ./.)
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   begins/NNS
#   with/IN
#   keeping/VBG
#   our/PRP$
#   economy/NN
#   growing/VBG
#   ./.)
# (S
#   And/CC
#   our/PRP$
#   economy/NN
#   grows/VBZ
#   when/WRB
#   (GPE Americans/NNPS)
#   have/VBP
#   more/JJR
#   of/IN
#   their/PRP$
#   own/JJ
#   money/NN
#   to/TO
#   spend/VB
#   ,/,
#   save/VB
#   ,/,
#   and/CC
#   invest/JJS
#   ./.)
# (S
#   In/IN
#   the/DT
#   last/JJ
#   five/CD
#   years/NNS
#   ,/,
#   the/DT
#   tax/NN
#   relief/NN
#   you/PRP
#   passed/VBD
#   has/VBZ
#   left/VBN
#   $/$
#   880/CD
#   billion/CD
#   in/IN
#   the/DT
#   hands/NNS
#   of/IN
#   (GPE American/NNP)
#   workers/NNS
#   ,/,
#   investors/NNS
#   ,/,
#   small/JJ
#   businesses/NNS
#   ,/,
#   and/CC
#   families/NNS
#   --/:
#   and/CC
#   they/PRP
#   have/VBP
#   used/VBN
#   it/PRP
#   to/TO
#   help/VB
#   produce/NN
#   more/JJR
#   than/IN
#   four/CD
#   years/NNS
#   of/IN
#   uninterrupted/JJ
#   economic/JJ
#   growth/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Yet/CC
#   the/DT
#   tax/NN
#   relief/NN
#   is/VBZ
#   set/VBN
#   to/TO
#   expire/VB
#   in/IN
#   the/DT
#   next/JJ
#   few/JJ
#   years/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   do/VBP
#   nothing/NN
#   ,/,
#   (GPE American/JJ)
#   families/NNS
#   will/MD
#   face/VB
#   a/DT
#   massive/JJ
#   tax/NN
#   increase/NN
#   they/PRP
#   do/VBP
#   not/RB
#   expect/VB
#   and/CC
#   will/MD
#   not/RB
#   welcome/VB
#   ./.)
# (S
#   Because/IN
#   (GPE America/NNP)
#   needs/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   temporary/JJ
#   expansion/NN
#   ,/,
#   we/PRP
#   need/VBP
#   more/JJR
#   than/IN
#   temporary/JJ
#   tax/NN
#   relief/NN
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   the/DT
#   (ORGANIZATION Congress/NNP)
#   to/TO
#   act/VB
#   responsibly/RB
#   ,/,
#   and/CC
#   make/VB
#   the/DT
#   tax/NN
#   cuts/NNS
#   permanent/JJ
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/NNS
#   us/PRP
#   to/TO
#   be/VB
#   good/JJ
#   stewards/NNS
#   of/IN
#   tax/NN
#   dollars/NNS
#   ./.)
# (S
#   Every/DT
#   year/NN
#   of/IN
#   my/PRP$
#   presidency/NN
#   ,/,
#   we/PRP
#   've/VBP
#   reduced/VBN
#   the/DT
#   growth/NN
#   of/IN
#   non-security/NN
#   discretionary/JJ
#   spending/NN
#   ,/,
#   and/CC
#   last/JJ
#   year/NN
#   you/PRP
#   passed/VBD
#   bills/NNS
#   that/IN
#   cut/NN
#   this/DT
#   spending/NN
#   ./.)
# (S
#   This/DT
#   year/NN
#   my/PRP$
#   budget/NN
#   will/MD
#   cut/VB
#   it/PRP
#   again/RB
#   ,/,
#   and/CC
#   reduce/VB
#   or/CC
#   eliminate/VB
#   more/RBR
#   than/IN
#   140/CD
#   programs/NNS
#   that/WDT
#   are/VBP
#   performing/VBG
#   poorly/RB
#   or/CC
#   not/RB
#   fulfilling/VBG
#   essential/JJ
#   priorities/NNS
#   ./.)
# (S
#   By/IN
#   passing/NN
#   these/DT
#   reforms/NNS
#   ,/,
#   we/PRP
#   will/MD
#   save/VB
#   the/DT
#   (GPE American/NNP)
#   taxpayer/NN
#   another/DT
#   $/$
#   14/CD
#   billion/CD
#   next/JJ
#   year/NN
#   ,/,
#   and/CC
#   stay/NN
#   on/IN
#   track/NN
#   to/TO
#   cut/VB
#   the/DT
#   deficit/NN
#   in/IN
#   half/DT
#   by/IN
#   2009/CD
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   I/PRP
#   am/VBP
#   pleased/VBN
#   that/IN
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   are/VBP
#   working/VBG
#   on/IN
#   earmark/NN
#   reform/NN
#   ,/,
#   because/IN
#   the/DT
#   federal/JJ
#   budget/NN
#   has/VBZ
#   too/RB
#   many/JJ
#   special/JJ
#   interest/NN
#   projects/NNS
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   And/CC
#   we/PRP
#   can/MD
#   tackle/VB
#   this/DT
#   problem/NN
#   together/RP
#   ,/,
#   if/IN
#   you/PRP
#   pass/VBP
#   the/DT
#   line-item/JJ
#   veto/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   We/PRP
#   must/MD
#   also/RB
#   confront/VB
#   the/DT
#   larger/JJR
#   challenge/NN
#   of/IN
#   mandatory/NN
#   spending/NN
#   ,/,
#   or/CC
#   entitlements/NNS
#   ./.)
# (S
#   This/DT
#   year/NN
#   ,/,
#   the/DT
#   first/JJ
#   of/IN
#   about/RB
#   78/CD
#   million/CD
#   baby/NN
#   boomers/NNS
#   turn/VBP
#   60/CD
#   ,/,
#   including/VBG
#   two/CD
#   of/IN
#   my/PRP$
#   (GPE Dad/NNP)
#   's/POS
#   favorite/JJ
#   people/NNS
#   --/:
#   me/PRP
#   and/CC
#   President/NNP
#   (PERSON Clinton/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Laughter/NNP) ./. )/:)
# (S
#   This/DT
#   milestone/NN
#   is/VBZ
#   more/RBR
#   than/IN
#   a/DT
#   personal/JJ
#   crisis/NN
#   --/:
#   (/CD
#   laughter/NN
#   )/:
#   --/:
#   it/PRP
#   is/VBZ
#   a/DT
#   national/JJ
#   challenge/NN
#   ./.)
# (S
#   The/DT
#   retirement/NN
#   of/IN
#   the/DT
#   baby/NN
#   boom/NN
#   generation/NN
#   will/MD
#   put/VB
#   unprecedented/VBN
#   strains/NNS
#   on/IN
#   the/DT
#   federal/JJ
#   government/NN
#   ./.)
# (S
#   By/IN
#   2030/CD
#   ,/,
#   spending/NN
#   for/IN
#   (ORGANIZATION Social/JJ)
#   (ORGANIZATION Security/NN)
#   ,/,
#   (ORGANIZATION Medicare/NNP)
#   and/CC
#   (PERSON Medicaid/NNP)
#   alone/RB
#   will/MD
#   be/VB
#   almost/RB
#   60/CD
#   percent/NN
#   of/IN
#   the/DT
#   entire/JJ
#   federal/JJ
#   budget/NN
#   ./.)
# (S
#   And/CC
#   that/DT
#   will/MD
#   present/VB
#   future/JJ
#   Congresses/NNS
#   with/IN
#   impossible/JJ
#   choices/NNS
#   --/:
#   staggering/VBG
#   tax/NN
#   increases/NNS
#   ,/,
#   immense/NN
#   deficits/NNS
#   ,/,
#   or/CC
#   deep/VB
#   cuts/NNS
#   in/IN
#   every/DT
#   category/NN
#   of/IN
#   spending/NN
#   ./.)
# (S
#   (ORGANIZATION Congress/NNP)
#   did/VBD
#   not/RB
#   act/VB
#   last/JJ
#   year/NN
#   on/IN
#   my/PRP$
#   proposal/NN
#   to/TO
#   save/VB
#   (ORGANIZATION Social/JJ)
#   (ORGANIZATION Security/NN)
#   --/:
#   (/CD
#   applause/NN
#   )/:
#   --/:
#   yet/RB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   entitlements/NNS
#   is/VBZ
#   a/DT
#   problem/NN
#   that/WDT
#   is/VBZ
#   not/RB
#   going/VBG
#   away/RB
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   And/CC
#   every/DT
#   year/NN
#   we/PRP
#   fail/VBP
#   to/TO
#   act/VB
#   ,/,
#   the/DT
#   situation/NN
#   gets/VBZ
#   worse/NN
#   ./.)
# (S
#   So/IN
#   tonight/NN
#   ,/,
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   join/VB
#   me/PRP
#   in/IN
#   creating/VBG
#   a/DT
#   commission/NN
#   to/TO
#   examine/VB
#   the/DT
#   full/JJ
#   impact/NN
#   of/IN
#   baby/NN
#   boom/NN
#   retirements/NNS
#   on/IN
#   (ORGANIZATION Social/NNP)
#   Security/NNP
#   ,/,
#   (GPE Medicare/NNP)
#   ,/,
#   and/CC
#   (ORGANIZATION Medicaid/NNP)
#   ./.)
# (S
#   This/DT
#   commission/NN
#   should/MD
#   include/VB
#   members/NNS
#   of/IN
#   (ORGANIZATION Congress/NNP)
#   of/IN
#   both/DT
#   parties/NNS
#   ,/,
#   and/CC
#   offer/NN
#   bipartisan/NN
#   solutions/NNS
#   ./.)
# (S
#   We/PRP
#   need/VBP
#   to/TO
#   put/VB
#   aside/JJ
#   partisan/NN
#   politics/NNS
#   and/CC
#   work/VB
#   together/RP
#   and/CC
#   get/VB
#   this/DT
#   problem/NN
#   solved/VBD
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/NNS
#   us/PRP
#   to/TO
#   open/VB
#   more/JJR
#   markets/NNS
#   for/IN
#   all/DT
#   that/DT
#   Americans/NNPS
#   make/VBP
#   and/CC
#   grow/NN
#   ./.)
# (S
#   One/CD
#   out/IN
#   of/IN
#   every/DT
#   five/CD
#   factory/NN
#   jobs/NNS
#   in/IN
#   (GPE America/NNP)
#   is/VBZ
#   related/VBN
#   to/TO
#   global/JJ
#   trade/NN
#   ,/,
#   and/CC
#   we/PRP
#   want/VBP
#   people/NNS
#   everywhere/RB
#   to/TO
#   buy/VB
#   (GPE American/JJ)
#   ./.)
# (S
#   With/IN
#   open/JJ
#   markets/NNS
#   and/CC
#   a/DT
#   level/NN
#   playing/NN
#   field/NN
#   ,/,
#   no/DT
#   one/PRP
#   can/MD
#   out-produce/VB
#   or/CC
#   out-compete/JJ
#   the/DT
#   (GPE American/NNP)
#   worker/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/NNS
#   an/DT
#   immigration/NN
#   system/NN
#   that/WDT
#   upholds/VBZ
#   our/PRP$
#   laws/NNS
#   ,/,
#   reflects/NNS
#   our/PRP$
#   values/NNS
#   ,/,
#   and/CC
#   serves/NNS
#   the/DT
#   interests/NNS
#   of/IN
#   our/PRP$
#   economy/NN
#   ./.)
# (S
#   Our/PRP$
#   nation/NN
#   needs/VBZ
#   orderly/RB
#   and/CC
#   secure/NN
#   borders/NNS
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   To/TO
#   meet/VB
#   this/DT
#   goal/NN
#   ,/,
#   we/PRP
#   must/MD
#   have/VB
#   stronger/JJR
#   immigration/NN
#   enforcement/NN
#   and/CC
#   border/NN
#   protection/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   And/CC
#   we/PRP
#   must/MD
#   have/VB
#   a/DT
#   rational/JJ
#   ,/,
#   humane/NN
#   guest/NN
#   worker/NN
#   program/NN
#   that/WDT
#   rejects/VBZ
#   amnesty/NN
#   ,/,
#   allows/VBZ
#   temporary/JJ
#   jobs/NNS
#   for/IN
#   people/NNS
#   who/WP
#   seek/NN
#   them/PRP
#   legally/RB
#   ,/,
#   and/CC
#   reduces/NNS
#   smuggling/VBG
#   and/CC
#   crime/NN
#   at/IN
#   the/DT
#   border/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Keeping/VBG
#   (GPE America/NNP)
#   competitive/JJ
#   requires/NNS
#   affordable/JJ
#   health/NN
#   care/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Our/PRP$
#   government/NN
#   has/VBZ
#   a/DT
#   responsibility/NN
#   to/TO
#   provide/VB
#   health/NN
#   care/NN
#   for/IN
#   the/DT
#   poor/JJ
#   and/CC
#   the/DT
#   elderly/JJ
#   ,/,
#   and/CC
#   we/PRP
#   are/VBP
#   meeting/VBG
#   that/IN
#   responsibility/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   For/IN
#   all/DT
#   Americans/NNPS
#   --/:
#   for/IN
#   all/PDT
#   Americans/NNPS
#   ,/,
#   we/PRP
#   must/MD
#   confront/VB
#   the/DT
#   rising/VBG
#   cost/NN
#   of/IN
#   care/NN
#   ,/,
#   strengthen/RB
#   the/DT
#   doctor-patient/JJ
#   relationship/NN
#   ,/,
#   and/CC
#   help/VB
#   people/NNS
#   afford/VB
#   the/DT
#   insurance/NN
#   coverage/NN
#   they/PRP
#   need/VBP
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   We/PRP
#   will/MD
#   make/VB
#   wider/NN
#   use/NN
#   of/IN
#   electronic/JJ
# ...
#   to/TO
#   train/VB
#   70,000/CD
#   high/JJ
#   school/NN
#   teachers/NNS
#   to/TO
#   lead/VB
#   advanced-placement/JJ
#   courses/NNS
#   in/IN
#   math/NN
#   and/CC
#   science/NN
#   ,/,
#   bring/VB
#   30,000/CD
#   math/NN
#   and/CC
#   science/NN
#   professionals/NNS
#   to/TO
#   teach/VB
#   in/IN
#   classrooms/NNS
#   ,/,
#   and/CC
#   give/VB
#   early/JJ
#   help/NN
#   to/TO
#   students/NNS
#   who/WP
#   struggle/NN
#   with/IN
#   math/NN
#   ,/,
#   so/RB
#   they/PRP
#   have/VBP
#   a/DT
#   better/JJR
#   chance/NN
#   at/IN
#   good/JJ
#   ,/,
#   high-wage/JJ
#   jobs/NNS
#   ./.)
# (S
#   If/IN
#   we/PRP
#   ensure/VBP
#   that/IN
#   (GPE America/NNP)
#   's/POS
#   children/NNS
#   succeed/VBD
#   in/IN
#   life/NN
#   ,/,
#   they/PRP
#   will/MD
#   ensure/VB
#   that/IN
#   (GPE America/NNP)
#   succeeds/NNS
#   in/IN
#   the/DT
#   world/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Preparing/VBG
#   our/PRP$
#   nation/NN
#   to/TO
#   compete/VB
#   in/IN
#   the/DT
#   world/NN
#   is/VBZ
#   a/DT
#   goal/NN
#   that/WDT
#   all/DT
#   of/IN
#   us/PRP
#   can/MD
#   share/VB
#   ./.)
# (S
#   I/PRP
#   urge/VBP
#   you/PRP
#   to/TO
#   support/VB
#   the/DT
#   (ORGANIZATION American/NNP Competitiveness/NNP Initiative/NNP)
#   ,/,
#   and/CC
#   together/RB
#   we/PRP
#   will/MD
#   show/VB
#   the/DT
#   world/NN
#   what/WP
#   the/DT
#   (GPE American/NNP)
#   people/NNS
#   can/MD
#   achieve/VB
#   ./.)
# (S
#   (GPE America/NNP)
#   is/VBZ
#   a/DT
#   great/JJ
#   force/NN
#   for/IN
#   freedom/NN
#   and/CC
#   prosperity/NN
#   ./.)
# (S
#   Yet/CC
#   our/PRP$
#   greatness/NN
#   is/VBZ
#   not/RB
#   measured/VBN
#   in/IN
#   power/NN
#   or/CC
#   luxuries/NNS
#   ,/,
#   but/CC
#   by/IN
#   who/WP
#   we/PRP
#   are/VBP
#   and/CC
#   how/WRB
#   we/PRP
#   treat/VBP
#   one/CD
#   another/DT
#   ./.)
# (S
#   So/IN
#   we/PRP
#   strive/VBP
#   to/TO
#   be/VB
#   a/DT
#   compassionate/NN
#   ,/,
#   decent/NN
#   ,/,
#   hopeful/JJ
#   society/NN
#   ./.)
# (S
#   In/IN
#   recent/JJ
#   years/NNS
#   ,/,
#   (GPE America/NNP)
#   has/VBZ
#   become/VBN
#   a/DT
#   more/RBR
#   hopeful/JJ
#   nation/NN
#   ./.)
# (S
#   (GPE Violent/NNP)
#   crime/NN
#   rates/NNS
#   have/VBP
#   fallen/VBN
#   to/TO
#   their/PRP$
#   lowest/JJS
#   levels/NNS
#   since/IN
#   the/DT
#   1970s/CD
#   ./.)
# (S
#   (GPE Welfare/NNP)
#   cases/NNS
#   have/VBP
#   dropped/VBN
#   by/IN
#   more/RBR
#   than/IN
#   half/PDT
#   over/IN
#   the/DT
#   past/JJ
#   decade/NN
#   ./.)
# (S
#   (GPE Drug/NN)
#   use/NN
#   among/IN
#   youth/NN
#   is/VBZ
#   down/IN
#   19/CD
#   percent/NN
#   since/IN
#   2001/CD
#   ./.)
# (S
#   There/EX
#   are/VBP
#   fewer/JJR
#   abortions/NNS
#   in/IN
#   (GPE America/NNP)
#   than/IN
#   at/IN
#   any/DT
#   point/NN
#   in/IN
#   the/DT
#   last/JJ
#   three/CD
#   decades/NNS
#   ,/,
#   and/CC
#   the/DT
#   number/NN
#   of/IN
#   children/NNS
#   born/VBP
#   to/TO
#   teenage/NN
#   mothers/NNS
#   has/VBZ
#   been/VBN
#   falling/VBG
#   for/IN
#   a/DT
#   dozen/NN
#   years/NNS
#   in/IN
#   a/DT
#   row/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   These/DT
#   gains/NNS
#   are/VBP
#   evidence/NN
#   of/IN
#   a/DT
#   quiet/JJ
#   transformation/NN
#   --/:
#   a/DT
#   revolution/NN
#   of/IN
#   conscience/NN
#   ,/,
#   in/IN
#   which/WDT
#   a/DT
#   rising/VBG
#   generation/NN
#   is/VBZ
#   finding/VBG
#   that/IN
#   a/DT
#   life/NN
#   of/IN
#   personal/JJ
#   responsibility/NN
#   is/VBZ
#   a/DT
#   life/NN
#   of/IN
#   fulfillment/NN
#   ./.)
# (S Government/NNP has/VBZ played/VBN a/DT role/NN ./.)
# (S
#   (GPE Wise/NNP)
#   policies/NNS
#   ,/,
#   such/JJ
#   as/IN
#   welfare/NN
#   reform/NN
#   and/CC
#   drug/NN
#   education/NN
#   and/CC
#   support/NN
#   for/IN
#   abstinence/NN
#   and/CC
#   adoption/NN
#   have/VBP
#   made/VBN
#   a/DT
#   difference/NN
#   in/IN
#   the/DT
#   character/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   And/CC
#   everyone/NN
#   here/RB
#   tonight/VBD
#   ,/,
#   (ORGANIZATION Democrat/NNP)
#   and/CC
#   (ORGANIZATION Republican/NNP)
#   ,/,
#   has/VBZ
#   a/DT
#   right/NN
#   to/TO
#   be/VB
#   proud/VBN
#   of/IN
#   this/DT
#   record/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Yet/CC
#   many/JJ
#   Americans/NNPS
#   ,/,
#   especially/RB
#   parents/NNS
#   ,/,
#   still/RB
#   have/VBP
#   deep/VBN
#   concerns/NNS
#   about/IN
#   the/DT
#   direction/NN
#   of/IN
#   our/PRP$
#   culture/NN
#   ,/,
#   and/CC
#   the/DT
#   health/NN
#   of/IN
#   our/PRP$
#   most/RBS
#   basic/JJ
#   institutions/NNS
#   ./.)
# (S
#   They/PRP
#   're/VBP
#   concerned/VBN
#   about/IN
#   unethical/JJ
#   conduct/NN
#   by/IN
#   public/JJ
#   officials/NNS
#   ,/,
#   and/CC
#   discouraged/VBD
#   by/IN
#   activist/NN
#   courts/NNS
#   that/WDT
#   try/NN
#   to/TO
#   redefine/VB
#   marriage/NN
#   ./.)
# (S
#   They/PRP
#   worry/VBP
#   about/IN
#   children/NNS
#   in/IN
#   our/PRP$
#   society/NN
#   who/WP
#   need/VBP
#   direction/NN
#   and/CC
#   love/VB
#   ,/,
#   and/CC
#   about/IN
#   fellow/JJ
#   citizens/NNS
#   still/RB
#   displaced/VBN
#   by/IN
#   natural/JJ
#   disaster/NN
#   ,/,
#   and/CC
#   about/IN
#   suffering/VBG
#   caused/VBN
#   by/IN
#   treatable/JJ
#   diseases/NNS
#   ./.)
# (S
#   As/IN
#   we/PRP
#   look/VBP
#   at/IN
#   these/DT
#   challenges/NNS
#   ,/,
#   we/PRP
#   must/MD
#   never/RB
#   give/VB
#   in/IN
#   to/TO
#   the/DT
#   belief/NN
#   that/IN
#   (GPE America/NNP)
#   is/VBZ
#   in/IN
#   decline/NN
#   ,/,
#   or/CC
#   that/IN
#   our/PRP$
#   culture/NN
#   is/VBZ
#   doomed/VBN
#   to/TO
#   unravel/VB
#   ./.)
# (S
#   The/DT
#   (GPE American/NNP)
#   people/NNS
#   know/VB
#   better/JJR
#   than/IN
#   that/DT
#   ./.)
# (S
#   We/PRP
#   have/VBP
#   proven/VBN
#   the/DT
#   pessimists/NNS
#   wrong/JJ
#   before/IN
#   --/:
#   and/CC
#   we/PRP
#   will/MD
#   do/VB
#   it/PRP
#   again/RB
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   depends/NNS
#   on/IN
#   courts/NNS
#   that/IN
#   deliver/NN
#   equal/JJ
#   justice/NN
#   under/IN
#   the/DT
#   law/NN
#   ./.)
# (S
#   The/DT
#   (ORGANIZATION Supreme/NNP Court/NNP)
#   now/RB
#   has/VBZ
#   two/CD
#   superb/NN
#   new/JJ
#   members/NNS
#   --/:
#   new/JJ
#   members/NNS
#   on/IN
#   its/PRP$
#   bench/NN
#   :/:
#   Chief/JJ
#   Justice/NNP
#   (PERSON John/NNP Roberts/NNP)
#   and/CC
#   (ORGANIZATION Justice/NNP Sam/NNP Alito/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   I/PRP
#   thank/VBP
#   the/DT
#   (ORGANIZATION Senate/NNP)
#   for/IN
#   confirming/VBG
#   both/DT
#   of/IN
#   them/PRP
#   ./.)
# (S
#   I/PRP
#   will/MD
#   continue/VB
#   to/TO
#   nominate/VB
#   men/NNS
#   and/CC
#   women/NNS
#   who/WP
#   understand/VBP
#   that/IN
#   judges/NNS
#   must/MD
#   be/VB
#   servants/NNS
#   of/IN
#   the/DT
#   law/NN
#   ,/,
#   and/CC
#   not/RB
#   legislate/VB
#   from/IN
#   the/DT
#   bench/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   Today/NN
#   marks/NNS
#   the/DT
#   official/NN
#   retirement/NN
#   of/IN
#   a/DT
#   very/RB
#   special/JJ
#   (GPE American/JJ)
#   ./.)
# (S
#   For/IN
#   24/CD
#   years/NNS
#   of/IN
#   faithful/JJ
#   service/NN
#   to/TO
#   our/PRP$
#   nation/NN
#   ,/,
#   the/DT
#   (GPE United/NNP States/NNPS)
#   is/VBZ
#   grateful/JJ
#   to/TO
#   (ORGANIZATION Justice/NNP Sandra/NNP)
#   Day/NNP
#   O'Connor/NNP
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   has/VBZ
#   institutions/NNS
#   of/IN
#   science/NN
#   and/CC
#   medicine/NN
#   that/IN
#   do/VB
#   not/RB
#   cut/VB
#   ethical/JJ
#   corners/NNS
#   ,/,
#   and/CC
#   that/IN
#   recognize/NN
#   the/DT
#   matchless/NN
#   value/NN
#   of/IN
#   every/DT
#   life/NN
#   ./.)
# (S
#   Tonight/NNP
#   I/PRP
#   ask/VBP
#   you/PRP
#   to/TO
#   pass/VB
#   legislation/NN
#   to/TO
#   prohibit/VB
#   the/DT
#   most/JJS
#   egregious/JJ
#   abuses/NNS
#   of/IN
#   medical/JJ
#   research/NN
#   :/:
#   human/JJ
#   cloning/NN
#   in/IN
#   all/DT
#   its/PRP$
#   forms/NNS
#   ,/,
#   creating/VBG
#   or/CC
#   implanting/VBG
#   embryos/NNS
#   for/IN
#   experiments/NNS
#   ,/,
#   creating/VBG
#   human-animal/JJ
#   hybrids/NNS
#   ,/,
#   and/CC
#   buying/NN
#   ,/,
#   selling/VBG
#   ,/,
#   or/CC
#   patenting/VBG
#   human/JJ
#   embryos/NNS
#   ./.)
# (S
#   (GPE Human/NNP)
#   life/NN
#   is/VBZ
#   a/DT
#   gift/NN
#   from/IN
#   our/PRP$
#   Creator/NNP
#   --/:
#   and/CC
#   that/IN
#   gift/NN
#   should/MD
#   never/RB
#   be/VB
#   discarded/VBN
#   ,/,
#   devalued/VBN
#   or/CC
#   put/VBN
#   up/RP
#   for/IN
#   sale/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   expects/VBZ
#   elected/VBN
#   officials/NNS
#   to/TO
#   uphold/VB
#   the/DT
#   public/NN
#   trust/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (GPE Honorable/JJ)
#   people/NNS
#   in/IN
#   both/DT
#   parties/NNS
#   are/VBP
#   working/VBG
#   on/IN
#   reforms/NNS
#   to/TO
#   strengthen/VB
#   the/DT
#   ethical/JJ
#   standards/NNS
#   of/IN
#   (GPE Washington/NNP)
#   --/:
#   I/PRP
#   support/VBP
#   your/PRP$
#   efforts/NNS
#   ./.)
# (S
#   Each/DT
#   of/IN
#   us/PRP
#   has/VBZ
#   made/VBN
#   a/DT
#   pledge/NN
#   to/TO
#   be/VB
#   worthy/JJ
#   of/IN
#   public/JJ
#   responsibility/NN
#   --/:
#   and/CC
#   that/IN
#   is/VBZ
#   a/DT
#   pledge/NN
#   we/PRP
#   must/MD
#   never/RB
#   forget/VB
#   ,/,
#   never/RB
#   dismiss/VBZ
#   ,/,
#   and/CC
#   never/RB
#   betray/VBP
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   As/IN
#   we/PRP
#   renew/VBP
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   institutions/NNS
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   show/VBP
#   the/DT
#   character/NN
#   of/IN
#   (GPE America/NNP)
#   in/IN
#   our/PRP$
#   compassion/NN
#   and/CC
#   care/NN
#   for/IN
#   one/CD
#   another/DT
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   gives/VBZ
#   special/JJ
#   attention/NN
#   to/TO
#   children/NNS
#   who/WP
#   lack/VBP
#   direction/NN
#   and/CC
#   love/VB
#   ./.)
# (S
#   Through/IN
#   the/DT
#   (ORGANIZATION Helping/NNP America/NNP)
#   's/POS
#   Youth/NNP
#   Initiative/NNP
#   ,/,
#   we/PRP
#   are/VBP
#   encouraging/VBG
#   caring/VBG
#   adults/NNS
#   to/TO
#   get/VB
#   involved/VBN
#   in/IN
#   the/DT
#   life/NN
#   of/IN
#   a/DT
#   child/NN
#   --/:
#   and/CC
#   this/DT
#   good/JJ
#   work/NN
#   is/VBZ
#   being/VBG
#   led/VBN
#   by/IN
#   our/PRP$
#   First/NNP
#   Lady/NNP
#   ,/,
#   (PERSON Laura/NNP Bush/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   This/DT
#   year/NN
#   we/PRP
#   will/MD
#   add/VB
#   resources/NNS
#   to/TO
#   encourage/VB
#   young/JJ
#   people/NNS
#   to/TO
#   stay/VB
#   in/IN
#   school/NN
#   ,/,
#   so/RB
#   more/RBR
#   of/IN
#   (GPE America/NNP)
#   's/POS
#   youth/NN
#   can/MD
#   raise/VB
#   their/PRP$
#   sights/NNS
#   and/CC
#   achieve/VB
#   their/PRP$
#   dreams/NNS
#   ./.)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   comes/VBZ
#   to/TO
#   the/DT
#   aid/NN
#   of/IN
#   fellow/JJ
#   citizens/NNS
#   in/IN
#   times/NNS
#   of/IN
#   suffering/NN
#   and/CC
#   emergency/NN
#   --/:
#   and/CC
#   stays/NNS
#   at/IN
#   it/PRP
#   until/IN
#   they/PRP
#   're/VBP
#   back/RB
#   on/IN
#   their/PRP$
#   feet/NN
#   ./.)
# (S
#   So/IN
#   far/RB
#   the/DT
#   federal/JJ
#   government/NN
#   has/VBZ
#   committed/VBN
#   $/$
#   85/CD
#   billion/CD
#   to/TO
#   the/DT
#   people/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Gulf/NNP Coast/NNP)
#   and/CC
#   (GSP New/NNP Orleans/NNP)
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   removing/VBG
#   debris/NNS
#   and/CC
#   repairing/VBG
#   highways/NNS
#   and/CC
#   rebuilding/VBG
#   stronger/JJR
#   levees/NNS
#   ./.)
# (S
#   We/PRP
#   're/VBP
#   providing/VBG
#   business/NN
#   loans/NNS
#   and/CC
#   housing/VBG
#   assistance/NN
#   ./.)
# (S
#   Yet/CC
#   as/IN
#   we/PRP
#   meet/VBP
#   these/DT
#   immediate/JJ
#   needs/NNS
#   ,/,
#   we/PRP
#   must/MD
#   also/RB
#   address/VB
#   deeper/JJR
#   challenges/NNS
#   that/WDT
#   existed/VBN
#   before/IN
#   the/DT
#   storm/NN
#   arrived/VBD
#   ./.)
# (S
#   In/IN
#   (GSP New/NNP Orleans/NNP)
#   and/CC
#   in/IN
#   other/JJ
#   places/NNS
#   ,/,
#   many/JJ
#   of/IN
#   our/PRP$
#   fellow/JJ
#   citizens/NNS
#   have/VBP
#   felt/VBN
#   excluded/VBN
#   from/IN
#   the/DT
#   promise/NN
#   of/IN
#   our/PRP$
#   country/NN
#   ./.)
# (S
#   The/DT
#   answer/NN
#   is/VBZ
#   not/RB
#   only/RB
#   temporary/JJ
#   relief/NN
#   ,/,
#   but/CC
#   schools/NNS
#   that/WDT
#   teach/VBP
#   every/DT
#   child/NN
#   ,/,
#   and/CC
#   job/NN
#   skills/NNS
#   that/WDT
#   bring/VBG
#   upward/NN
#   mobility/NN
#   ,/,
#   and/CC
#   more/JJR
#   opportunities/NNS
#   to/TO
#   own/VB
#   a/DT
#   home/NN
#   and/CC
#   start/VB
#   a/DT
#   business/NN
#   ./.)
# (S
#   As/IN
#   we/PRP
#   recover/RB
#   from/IN
#   a/DT
#   disaster/NN
#   ,/,
#   let/VB
#   us/PRP
#   also/RB
#   work/VBP
#   for/IN
#   the/DT
#   day/NN
#   when/WRB
#   all/DT
#   Americans/NNPS
#   are/VBP
#   protected/VBN
#   by/IN
#   justice/NN
#   ,/,
#   equal/JJ
#   in/IN
#   hope/NN
#   ,/,
#   and/CC
#   rich/JJ
#   in/IN
#   opportunity/NN
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   A/DT
#   hopeful/JJ
#   society/NN
#   acts/NNS
#   boldly/RB
#   to/TO
#   fight/VB
#   diseases/NNS
#   like/IN
#   HIV/AIDS/NNS
#   ,/,
#   which/WDT
#   can/MD
#   be/VB
#   prevented/VBN
#   ,/,
#   and/CC
#   treated/VBD
#   ,/,
#   and/CC
#   defeated/VBD
#   ./.)
# (S
#   More/JJR
#   than/IN
#   a/DT
#   million/NN
#   Americans/NNPS
#   live/JJ
#   with/IN
#   (ORGANIZATION HIV/NNP)
#   ,/,
#   and/CC
#   half/DT
#   of/IN
#   all/DT
#   AIDS/NNP
#   cases/NNS
#   occur/VBP
#   among/IN
#   (ORGANIZATION African/NNP Americans/NNPS)
#   ./.)
# (S
#   I/PRP
#   ask/VBP
#   (ORGANIZATION Congress/NNP)
#   to/TO
#   reform/VB
#   and/CC
#   reauthorize/VB
#   the/DT
#   (ORGANIZATION Ryan/NNP)
#   (FACILITY White/NNP Act/NNP)
#   ,/,
#   and/CC
#   provide/VB
#   new/JJ
#   funding/NN
#   to/TO
#   states/NNS
#   ,/,
#   so/RB
#   we/PRP
#   end/VBP
#   the/DT
#   waiting/VBG
#   lists/NNS
#   for/IN
#   (ORGANIZATION AIDS/NNP)
#   medicines/NNS
#   in/IN
#   (GPE America/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   We/PRP
#   will/MD
#   also/RB
#   lead/VB
#   a/DT
#   nationwide/JJ
#   effort/NN
#   ,/,
#   working/VBG
#   closely/RB
#   with/IN
#   (GSP African/JJ)
#   (GPE American/JJ)
#   churches/NNS
#   and/CC
#   faith-based/JJ
#   groups/NNS
#   ,/,
#   to/TO
#   deliver/VB
#   rapid/JJ
#   HIV/NNP
#   tests/NNS
#   to/TO
#   millions/NNS
#   ,/,
#   end/NN
#   the/DT
#   stigma/NN
#   of/IN
#   (ORGANIZATION AIDS/NNP)
#   ,/,
#   and/CC
#   come/VB
#   closer/NN
#   to/TO
#   the/DT
#   day/NN
#   when/WRB
#   there/EX
#   are/VBP
#   no/DT
#   new/JJ
#   infections/NNS
#   in/IN
#   (GPE America/NNP)
#   ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)
# (S
#   (GPE Fellow/NNP)
#   citizens/NNS
#   ,/,
#   we/PRP
#   've/VBP
#   been/VBN
#   called/VBN
#   to/TO
#   leadership/VB
#   in/IN
#   a/DT
#   period/NN
#   of/IN
#   consequence/NN
#   ./.)
# (S
#   We/PRP
#   've/VBP
#   entered/VBN
#   a/DT
#   great/JJ
#   ideological/JJ
#   conflict/NN
#   we/PRP
#   did/VBD
#   nothing/NN
#   to/TO
#   invite/VB
#   ./.)
# (S
#   We/PRP
#   see/VBP
#   great/JJ
#   changes/NNS
#   in/IN
#   science/NN
#   and/CC
#   commerce/NN
#   that/IN
#   will/MD
#   influence/VB
#   all/DT
#   our/PRP$
#   lives/NNS
#   ./.)
# (S
#   Sometimes/RB
#   it/PRP
#   can/MD
#   seem/VB
#   that/IN
#   history/NN
#   is/VBZ
#   turning/VBG
#   in/IN
#   a/DT
#   wide/JJ
#   arc/NN
#   ,/,
#   toward/IN
#   an/DT
#   unknown/NN
#   shore/NN
#   ./.)
# (S
#   Yet/CC
#   the/DT
#   destination/NN
#   of/IN
#   history/NN
#   is/VBZ
#   determined/VBN
#   by/IN
#   human/JJ
#   action/NN
#   ,/,
#   and/CC
#   every/DT
#   great/JJ
#   movement/NN
#   of/IN
#   history/NN
#   comes/VBZ
#   to/TO
#   a/DT
#   point/NN
#   of/IN
#   choosing/VBG
#   ./.)
# (S
#   (PERSON Lincoln/NNP)
#   could/MD
#   have/VB
#   accepted/VBN
#   peace/NN
#   at/IN
#   the/DT
#   cost/NN
#   of/IN
#   disunity/NN
#   and/CC
#   continued/VBD
#   slavery/NN
#   ./.)
# (S
#   (PERSON Martin/NNP)
#   (PERSON Luther/NNP King/NNP)
#   could/MD
#   have/VB
#   stopped/VBN
#   at/IN
#   (ORGANIZATION Birmingham/NNP)
#   or/CC
#   at/IN
#   (ORGANIZATION Selma/NNP)
#   ,/,
#   and/CC
#   achieved/VBD
#   only/RB
#   half/DT
#   a/DT
#   victory/NN
#   over/IN
#   segregation/NN
#   ./.)
# (S
#   The/DT
#   (GPE United/NNP States/NNPS)
#   could/MD
#   have/VB
#   accepted/VBN
#   the/DT
#   permanent/NN
#   division/NN
#   of/IN
#   (GPE Europe/NNP)
#   ,/,
#   and/CC
#   been/VBN
#   complicit/JJ
#   in/IN
#   the/DT
#   oppression/NN
#   of/IN
#   others/NNS
#   ./.)
# (S
#   Today/NN
#   ,/,
#   having/VBG
#   come/NN
#   far/RB
#   in/IN
#   our/PRP$
#   own/JJ
#   historical/JJ
#   journey/NN
#   ,/,
#   we/PRP
#   must/MD
#   decide/VB
#   :/:
#   Will/NNP
#   we/PRP
#   turn/VBP
#   back/RB
#   ,/,
#   or/CC
#   finish/JJ
#   well/NN
#   ?/.)
# (S
#   Before/IN
#   history/NN
#   is/VBZ
#   written/VBN
#   down/RP
#   in/IN
#   books/NNS
#   ,/,
#   it/PRP
#   is/VBZ
#   written/VBN
#   in/IN
#   courage/NN
#   ./.)
# (S
#   Like/IN
#   Americans/NNPS
#   before/IN
#   us/PRP
#   ,/,
#   we/PRP
#   will/MD
#   show/VB
#   that/IN
#   courage/NN
#   and/CC
#   we/PRP
#   will/MD
#   finish/VB
#   well/RB
#   ./.)
# (S We/PRP will/MD lead/VB freedom/NN 's/POS advance/NN ./.)
# (S
#   We/PRP
#   will/MD
#   compete/VB
#   and/CC
#   excel/NN
#   in/IN
#   the/DT
#   global/JJ
#   economy/NN
#   ./.)
# (S
#   We/PRP
#   will/MD
#   renew/VB
#   the/DT
#   defining/NN
#   moral/JJ
#   commitments/NNS
#   of/IN
#   this/DT
#   land/NN
#   ./.)
# (S
#   And/CC
#   so/RB
#   we/PRP
#   move/VBP
#   forward/RB
#   --/:
#   optimistic/JJ
#   about/IN
#   our/PRP$
#   country/NN
#   ,/,
#   faithful/JJ
#   to/TO
#   its/PRP$
#   cause/NN
#   ,/,
#   and/CC
#   confident/NN
#   of/IN
#   the/DT
#   victories/NNS
#   to/TO
#   come/VB
#   ./.)
# (S May/NNP God/NNP bless/NN (GPE America/NNP) ./.)
# (S (/NN (ORGANIZATION Applause/NNP) ./. )/:)

# %%
namedEnt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e79386b752d3> in <module>()
# ----> 1 namedEnt
#       2
#
# NameError: name 'namedEnt' is not defined
